# %%
import matplotlib.pyplot as plt
from nltk.parse import DependencyGraph
import networkx as nx
from itertools import chain

def generate_featuresets(annotations):
    def get_parent(word, sentence):
        for item in sentence:
            if item[0] == word[8]:
                return item
        return []
        
    def get_children(word, sentence):
         for item in sentence:
            if item[8] == word[0]:
                yield item
    
    def get_predicates(sentence):
        for word in sentence:
            if len(word)>1:
                if word[12] != "_":
                    yield word
                    
    def get_arguments(idx, predicate, sentence):
        arg = ""
        argdict = {}

        for word in sentence:
            try:
                arg = word[13+idx]
                if arg not in argdict:
                    argdict[arg] = [word]
                else:
                    argdict[arg].append(word)
                if arg != "":
                    if word[0] > predicate[0] and argdict[arg][0][0] < predicate[0]:
                        arg = ""
            except IndexError as e:
                print ("INFO: Predicate {} problem missing argument, skipping...".format(predicate[1]))
        return argdict
    
    def sentence_to_dict (sentence):
        dictionary = {}
        for word in sentence:
            dictionary[word[0]] = word
        return dictionary
    
    def sentence_to_graph (sentence):
        G=nx.Graph()
        for word in sentence:
            G.add_edge(word[0], word[9])
        return G
    
    def sentence_to_digraph (sentence):
        G=nx.DiGraph()
        for word in sentence:
            G.add_edge(word[9], word[0])
        return G
    
    
    def path_to_deprel (path, sentence_dict):
        predicate_idx = path[0][0]
        deprel = []
        for idx, item in enumerate(path[:-1], 1):
            first = item
            second = path[idx]
            direction = edge_direction((first, second), sentence_dict)
            label = sentence_dict[second][10]
            deprel.append ("{} {}".format(label, direction))
        return " ".join(deprel)
    
    def path_to_posrel (path, sentence_dict):
        predicate_idx = path[0][0]
        deprel = []
        for idx, item in enumerate(path[:-1], 1):
            first = item
            second = path[idx]
            direction = edge_direction((first, second), sentence_dict)
            label = sentence_dict[second][4]
            deprel.append ("{} {}".format(label, direction))
        return " ".join(deprel)
            
    def edge_direction (edge, sentence_dict):
        if sentence_dict[edge[0]][9] == edge[1]:
            return 'up'
        else:
            return 'down'
    def sentence_to_treebank(sentence):
        treebank = []
        for word in sentence:
            treebank.append("\t".join([word[1], word[4], word[9], word[10]]))
        return '\n'.join(treebank)
    
    def pprint_sentence (sentence):
        return ' '.join([word[1] for word in sentence]).replace(" ,", ",").replace(" .", ".").replace(" ?", "?").replace(" !", "?")
    for sentence in annotations:
        sentence_dict = sentence_to_dict(sentence)
        sentence_graph = sentence_to_graph(sentence)
        sentence_digraph = sentence_to_digraph(sentence)

        for idx, predicate in enumerate(get_predicates(sentence), 1):
            featuresets = []
            labels = []
            argdict = {}
            for argname, words in get_arguments(idx, predicate, sentence).items():
                for word in words:
                    argdict[word[0]] = argname
            for argument in sentence:
                if argument[0] != predicate[0]:
                    path = list(nx.shortest_path(sentence_graph, predicate[0], argument[0]))
                    featureset = {
                            'PredWord': predicate[1],
                            'PredPos': predicate[4],
                            'PredDeprel': predicate[10],
                            'PredFets': predicate[5],
                            'ArgWord':argument[1],
                            'ArgPos': argument[4],
                            'ArgDeprel': argument[10],
                            'ArgFets': argument[5],
                            'DeprelPath':path_to_deprel (path, sentence_dict),
                            'PosPath': path_to_posrel (path, sentence_dict),
                            'Position': int(argument[0]) > int(predicate[0]),
                    }

                    parent_word = get_parent(predicate, sentence)
                    if len(parent_word) > 0:
                        featureset['PredParentWord'] = parent_word[1]
                        featureset['PredParentPos'] = parent_word[4]
                        featureset['PredParentFeats'] = parent_word[6]

                    children_words = list(get_children(predicate, sentence))
                    if len(children_words)>0:
                        DepSubChildren = [predicate]
                        DepSubChildren.extend(children_words)

                        DepSubChildren = sorted(DepSubChildren, key=lambda x: x[0])
                        DepSubCat = ','.join([word[10] for word in DepSubChildren])
                        ChildDepSet = ','.join([word[10] for word in children_words])
                        ChildWordSet = ','.join([word[1] for word in children_words])
                        ChildPOSSet = ','.join([word[4] for word in children_words])

                        featureset['DepSubCat'] = DepSubCat
                        featureset['ChildDepSet'] = ChildDepSet
                        featureset['ChildWordSet'] = ChildWordSet
                        featureset['ChildPOSSet'] = ChildPOSSet

                    arg_parent = get_parent(argument, sentence)
                    if len(arg_parent) > 0:
                        children = list(get_children(arg_parent, sentence))
                        arg_children = list(get_children(argument, sentence))
                        
                        argument_index = children.index(argument)
                        if argument_index-1 > 0:
                            left = children[argument_index-1]
                            featureset['LeftSiblingWord'] = left[1]
                            featureset['LeftSiblingPos'] = left[4]
                            featureset['LeftSiblingFeats'] = left[5]
                        if argument_index+1 < len(children):
                            right = children[argument_index+1]
                            featureset['RightSiblingWord'] = right[1]
                            featureset['RightSiblingPos'] = right[4]
                            featureset['RightSiblingFeats'] = right[5]
                        if len(arg_children) > 1:
                            leftmost = arg_children[0]
                            featureset['LeftWord'] = leftmost[1]
                            featureset['LeftPos'] = leftmost[4]
                            featureset['LeftFeats'] = leftmost[5]

                            rightmost = arg_children[-1]
                            featureset['RightWord'] = rightmost[1]
                            featureset['RightPos'] = rightmost[4]
                            featureset['RightFeats'] = rightmost[3]
                    try:
                        labels.append(argument[13+idx] if argument[13+idx] != "_"  else "_")
                        featuresets.append (featureset)
                    except:
                        print ("INFO: Predicate {} has no arhuments in sentence {}".format(predicate[1], pprint_sentence(sentence)))
            yield featuresets, labels

# %%
def preprocess (filename):
    EOL = "\n"
    SEP = "\t"
    ETY = ""
    file = open(filename,"r")
    annotations = []
    annotation = []
    for line in file:
        parts = line.replace(EOL, ETY).split(SEP)
        if len(parts) > 1:
            annotation.append(parts)
        else:
            annotations.append(annotation)
            annotation = []
    print(annotations[1])
    print(list(generate_featuresets([annotations[1]])))
    return zip(*list(generate_featuresets(annotations)))

# %%
X_train, y_train = preprocess('data/hr.train.plus')
# Out:
# [['1', 'Kosovo', 'Kosovo', 'Kosovo', 'N', 'N', 'Type=proper|Gender=neuter|Number=singular|Case=nominative', 'Type=proper|Gender=neuter|Number=singular|Case=nominative', '3', '3', 'NSUBJ', 'NSUBJ', '_', '_', 'ACT'], ['2', 'ozbiljno', 'ozbiljno', 'ozbiljno', 'R', 'R', 'Type=general|Degree=positive', 'Type=general|Degree=positive', '3', '3', 'ADVMOD', 'ADVMOD', '_', '_', 'MANN'], ['3', 'analizira', 'analizirati', 'analizirati', 'V', 'V', 'Type=main|VForm=present|Person=third|Number=singular', 'Type=main|VForm=present|Person=third|Number=singular', '0', '0', 'ROOT', 'ROOT', 'Y', 'analizirati', '_'], ['4', 'proces', 'proces', 'proces', 'N', 'N', 'Type=common|Gender=masculine|Number=singular|Case=accusative|Animate=no', 'Type=common|Gender=masculine|Number=singular|Case=accusative|Animate=no', '3', '3', 'DOBJ', 'DOBJ', '_', '_', 'PAT'], ['5', 'privatizacije', 'privatizacija', 'privatizacija', 'N', 'N', 'Type=common|Gender=feminine|Number=singular|Case=genitive', 'Type=common|Gender=feminine|Number=singular|Case=genitive', '4', '4', 'NMOD', 'NMOD', '_', '_', '_'], ['6', 'u', 'u', 'u', 'S', 'S', 'Case=locative', 'Case=locative', '7', '7', 'CASE', 'CASE', '_', '_', '_'], ['7', 'svjetlu', 'svjetlo', 'svjetlo', 'N', 'N', 'Type=common|Gender=neuter|Number=singular|Case=locative', 'Type=common|Gender=neuter|Number=singular|Case=locative', '3', '3', 'NMOD', 'NMOD', '_', '_', 'REG'], ['8', 'učestalih', 'učestao', 'učestao', 'A', 'A', 'Type=general|Degree=positive|Gender=feminine|Number=plural|Case=genitive|Definiteness=yes', 'Type=general|Degree=positive|Gender=feminine|Number=plural|Case=genitive|Definiteness=yes', '9', '9', 'AMOD', 'AMOD', '_', '_', '_'], ['9', 'pritužbi', 'pritužba', 'pritužba', 'N', 'N', 'Type=common|Gender=feminine|Number=plural|Case=genitive', 'Type=common|Gender=feminine|Number=plural|Case=genitive', '7', '7', 'NMOD', 'NMOD', '_', '_', '_'], ['10', '.', '.', '.', 'Z', 'Z', '_', '_', '3', '3', 'PUNCT', 'PUNCT', '_', '_', '_']]
# [([{'PredWord': 'analizira', 'PredPos': 'V', 'PredDeprel': 'ROOT', 'PredFets': 'V', 'ArgWord': 'Kosovo', 'ArgPos': 'N', 'ArgDeprel': 'NSUBJ', 'ArgFets': 'N', 'DeprelPath': 'NSUBJ down', 'PosPath': 'N down', 'Position': False, 'DepSubCat': 'NSUBJ,PUNCT,ADVMOD,ROOT,DOBJ,NMOD', 'ChildDepSet': 'NSUBJ,ADVMOD,DOBJ,NMOD,PUNCT', 'ChildWordSet': 'Kosovo,ozbiljno,proces,svjetlu,.', 'ChildPOSSet': 'N,R,N,N,Z', 'RightSiblingWord': 'ozbiljno', 'RightSiblingPos': 'R', 'RightSiblingFeats': 'R'}, {'PredWord': 'analizira', 'PredPos': 'V', 'PredDeprel': 'ROOT', 'PredFets': 'V', 'ArgWord': 'ozbiljno', 'ArgPos': 'R', 'ArgDeprel': 'ADVMOD', 'ArgFets': 'R', 'DeprelPath': 'ADVMOD down', 'PosPath': 'R down', 'Position': False, 'DepSubCat': 'NSUBJ,PUNCT,ADVMOD,ROOT,DOBJ,NMOD', 'ChildDepSet': 'NSUBJ,ADVMOD,DOBJ,NMOD,PUNCT', 'ChildWordSet': 'Kosovo,ozbiljno,proces,svjetlu,.', 'ChildPOSSet': 'N,R,N,N,Z', 'RightSiblingWord': 'proces', 'RightSiblingPos': 'N', 'RightSiblingFeats': 'N'}, {'PredWord': 'analizira', 'PredPos': 'V', 'PredDeprel': 'ROOT', 'PredFets': 'V', 'ArgWord': 'proces', 'ArgPos': 'N', 'ArgDeprel': 'DOBJ', 'ArgFets': 'N', 'DeprelPath': 'DOBJ down', 'PosPath': 'N down', 'Position': True, 'DepSubCat': 'NSUBJ,PUNCT,ADVMOD,ROOT,DOBJ,NMOD', 'ChildDepSet': 'NSUBJ,ADVMOD,DOBJ,NMOD,PUNCT', 'ChildWordSet': 'Kosovo,ozbiljno,proces,svjetlu,.', 'ChildPOSSet': 'N,R,N,N,Z', 'LeftSiblingWord': 'ozbiljno', 'LeftSiblingPos': 'R', 'LeftSiblingFeats': 'R', 'RightSiblingWord': 'svjetlu', 'RightSiblingPos': 'N', 'RightSiblingFeats': 'N'}, {'PredWord': 'analizira', 'PredPos': 'V', 'PredDeprel': 'ROOT', 'PredFets': 'V', 'ArgWord': 'privatizacije', 'ArgPos': 'N', 'ArgDeprel': 'NMOD', 'ArgFets': 'N', 'DeprelPath': 'DOBJ down NMOD down', 'PosPath': 'N down N down', 'Position': True, 'DepSubCat': 'NSUBJ,PUNCT,ADVMOD,ROOT,DOBJ,NMOD', 'ChildDepSet': 'NSUBJ,ADVMOD,DOBJ,NMOD,PUNCT', 'ChildWordSet': 'Kosovo,ozbiljno,proces,svjetlu,.', 'ChildPOSSet': 'N,R,N,N,Z'}, {'PredWord': 'analizira', 'PredPos': 'V', 'PredDeprel': 'ROOT', 'PredFets': 'V', 'ArgWord': 'u', 'ArgPos': 'S', 'ArgDeprel': 'CASE', 'ArgFets': 'S', 'DeprelPath': 'NMOD down CASE down', 'PosPath': 'N down S down', 'Position': True, 'DepSubCat': 'NSUBJ,PUNCT,ADVMOD,ROOT,DOBJ,NMOD', 'ChildDepSet': 'NSUBJ,ADVMOD,DOBJ,NMOD,PUNCT', 'ChildWordSet': 'Kosovo,ozbiljno,proces,svjetlu,.', 'ChildPOSSet': 'N,R,N,N,Z', 'RightSiblingWord': 'pritužbi', 'RightSiblingPos': 'N', 'RightSiblingFeats': 'N'}, {'PredWord': 'analizira', 'PredPos': 'V', 'PredDeprel': 'ROOT', 'PredFets': 'V', 'ArgWord': 'svjetlu', 'ArgPos': 'N', 'ArgDeprel': 'NMOD', 'ArgFets': 'N', 'DeprelPath': 'NMOD down', 'PosPath': 'N down', 'Position': True, 'DepSubCat': 'NSUBJ,PUNCT,ADVMOD,ROOT,DOBJ,NMOD', 'ChildDepSet': 'NSUBJ,ADVMOD,DOBJ,NMOD,PUNCT', 'ChildWordSet': 'Kosovo,ozbiljno,proces,svjetlu,.', 'ChildPOSSet': 'N,R,N,N,Z', 'LeftSiblingWord': 'proces', 'LeftSiblingPos': 'N', 'LeftSiblingFeats': 'N', 'RightSiblingWord': '.', 'RightSiblingPos': 'Z', 'RightSiblingFeats': 'Z', 'LeftWord': 'u', 'LeftPos': 'S', 'LeftFeats': 'S', 'RightWord': 'pritužbi', 'RightPos': 'N', 'RightFeats': 'pritužba'}, {'PredWord': 'analizira', 'PredPos': 'V', 'PredDeprel': 'ROOT', 'PredFets': 'V', 'ArgWord': 'učestalih', 'ArgPos': 'A', 'ArgDeprel': 'AMOD', 'ArgFets': 'A', 'DeprelPath': 'NMOD down NMOD down AMOD down', 'PosPath': 'N down N down A down', 'Position': True, 'DepSubCat': 'NSUBJ,PUNCT,ADVMOD,ROOT,DOBJ,NMOD', 'ChildDepSet': 'NSUBJ,ADVMOD,DOBJ,NMOD,PUNCT', 'ChildWordSet': 'Kosovo,ozbiljno,proces,svjetlu,.', 'ChildPOSSet': 'N,R,N,N,Z'}, {'PredWord': 'analizira', 'PredPos': 'V', 'PredDeprel': 'ROOT', 'PredFets': 'V', 'ArgWord': 'pritužbi', 'ArgPos': 'N', 'ArgDeprel': 'NMOD', 'ArgFets': 'N', 'DeprelPath': 'NMOD down NMOD down', 'PosPath': 'N down N down', 'Position': True, 'DepSubCat': 'NSUBJ,PUNCT,ADVMOD,ROOT,DOBJ,NMOD', 'ChildDepSet': 'NSUBJ,ADVMOD,DOBJ,NMOD,PUNCT', 'ChildWordSet': 'Kosovo,ozbiljno,proces,svjetlu,.', 'ChildPOSSet': 'N,R,N,N,Z'}, {'PredWord': 'analizira', 'PredPos' ...

# %%
crf.predict([X_train[0]])
# Out:
# [['ACT', 'MANN', 'PAT', '_', '_', 'REG', '_', '_', '_']]

# %%
X_test, y_test = preprocess('data/hr.test.plus')
# Out:
# [['1', 'Vjeruje', 'vjerovati', 'vjerovati', 'V', 'V', 'Type=main|VForm=present|Person=third|Number=singular', 'Type=main|VForm=present|Person=third|Number=singular', '0', '0', 'ROOT', 'ROOT', 'Y', 'vjerovati', '_', '_'], ['2', 'se', 'sebe', 'sebe', 'P', 'P', 'Type=reflexive|Number=singular|Case=accusative', 'Type=reflexive|Number=singular|Case=accusative', '1', '1', 'COMPOUND', 'COMPOUND', '_', '_', '_', '_'], ['3', 'da', 'da', 'da', 'C', 'C', 'Type=subordinating', 'Type=subordinating', '7', '7', 'MARK', 'MARK', '_', '_', '_', '_'], ['4', 'se', 'sebe', 'sebe', 'P', 'P', 'Type=reflexive|Number=singular|Case=accusative', 'Type=reflexive|Number=singular|Case=accusative', '7', '7', 'COMPOUND', 'COMPOUND', '_', '_', '_', '_'], ['5', 'u', 'u', 'u', 'S', 'S', 'Case=locative', 'Case=locative', '6', '6', 'CASE', 'CASE', '_', '_', '_', '_'], ['6', 'Poljskoj', 'Poljska', 'Poljska', 'N', 'N', 'Type=proper|Gender=feminine|Number=singular|Case=locative', 'Type=proper|Gender=feminine|Number=singular|Case=locative', '7', '7', 'NMOD', 'NMOD', '_', '_', '_', 'LOC'], ['7', 'nalaze', 'nalaziti', 'nalaziti', 'V', 'V', 'Type=main|VForm=present|Person=third|Number=plural', 'Type=main|VForm=present|Person=third|Number=plural', '1', '1', 'CSUBJ', 'CSUBJ', 'Y', 'nalaziti', 'PAT', '_'], ['8', 'neke', 'neki', 'neki', 'P', 'P', 'Type=indefinite|Gender=feminine|Number=plural|Case=nominative', 'Type=indefinite|Gender=feminine|Number=plural|Case=nominative', '11', '11', 'AMOD', 'AMOD', '_', '_', '_', '_'], ['9', 'od', 'od', 'od', 'S', 'S', 'Case=genitive', 'Case=genitive', '11', '11', 'CASE', 'CASE', '_', '_', '_', '_'], ['10', 'najvećih', 'velik', 'velik', 'A', 'A', 'Type=general|Degree=superlative|Gender=feminine|Number=plural|Case=genitive|Definiteness=yes', 'Type=general|Degree=superlative|Gender=feminine|Number=plural|Case=genitive|Definiteness=yes', '11', '11', 'AMOD', 'AMOD', '_', '_', '_', '_'], ['11', 'pričuva', 'pričuva', 'pričuva', 'N', 'N', 'Type=common|Gender=feminine|Number=plural|Case=genitive', 'Type=common|Gender=feminine|Number=plural|Case=genitive', '7', '7', 'NSUBJ', 'NSUBJ', '_', '_', '_', 'ACT'], ['12', 'plina', 'plin', 'plin', 'N', 'N', 'Type=common|Gender=masculine|Number=singular|Case=genitive', 'Type=common|Gender=masculine|Number=singular|Case=genitive', '11', '11', 'NMOD', 'NMOD', '_', '_', '_', '_'], ['13', 'iz', 'iz', 'iz', 'S', 'S', 'Case=genitive', 'Case=genitive', '14', '14', 'CASE', 'CASE', '_', '_', '_', '_'], ['14', 'škriljevca', 'škriljevac', 'škriljevac', 'N', 'N', 'Type=common|Gender=masculine|Number=singular|Case=genitive', 'Type=common|Gender=masculine|Number=singular|Case=genitive', '12', '12', 'NMOD', 'NMOD', '_', '_', '_', '_'], ['15', 'u', 'u', 'u', 'S', 'S', 'Case=locative', 'Case=locative', '16', '16', 'CASE', 'CASE', '_', '_', '_', '_'], ['16', 'Europi', 'Europa', 'Europa', 'N', 'N', 'Type=proper|Gender=feminine|Number=singular|Case=locative', 'Type=proper|Gender=feminine|Number=singular|Case=locative', '11', '11', 'NMOD', 'NMOD', '_', '_', '_', '_'], ['17', '.', '.', '.', 'Z', 'Z', '_', '_', '1', '1', 'PUNCT', 'PUNCT', '_', '_', '_', '_']]
# [([{'PredWord': 'Vjeruje', 'PredPos': 'V', 'PredDeprel': 'ROOT', 'PredFets': 'V', 'ArgWord': 'se', 'ArgPos': 'P', 'ArgDeprel': 'COMPOUND', 'ArgFets': 'P', 'DeprelPath': 'COMPOUND down', 'PosPath': 'P down', 'Position': True, 'DepSubCat': 'ROOT,PUNCT,COMPOUND,CSUBJ', 'ChildDepSet': 'COMPOUND,CSUBJ,PUNCT', 'ChildWordSet': 'se,nalaze,.', 'ChildPOSSet': 'P,V,Z', 'RightSiblingWord': 'nalaze', 'RightSiblingPos': 'V', 'RightSiblingFeats': 'V'}, {'PredWord': 'Vjeruje', 'PredPos': 'V', 'PredDeprel': 'ROOT', 'PredFets': 'V', 'ArgWord': 'da', 'ArgPos': 'C', 'ArgDeprel': 'MARK', 'ArgFets': 'C', 'DeprelPath': 'CSUBJ down MARK down', 'PosPath': 'V down C down', 'Position': True, 'DepSubCat': 'ROOT,PUNCT,COMPOUND,CSUBJ', 'ChildDepSet': 'COMPOUND,CSUBJ,PUNCT', 'ChildWordSet': 'se,nalaze,.', 'ChildPOSSet': 'P,V,Z', 'RightSiblingWord': 'se', 'RightSiblingPos': 'P', 'RightSiblingFeats': 'P'}, {'PredWord': 'Vjeruje', 'PredPos': 'V', 'PredDeprel': 'ROOT', 'PredFets': 'V', 'ArgWord': 'se', 'ArgPos': 'P', 'ArgDeprel': 'COMPOUND', 'ArgFets': 'P', 'DeprelPath': 'CSUBJ down COMPOUND down', 'PosPath': 'V down P down', 'Position': True, 'DepSubCat': 'ROOT,PUNCT,COMPOUND,CSUBJ', 'ChildDepSet': 'COMPOUND,CSUBJ,PUNCT', 'ChildWordSet': 'se,nalaze,.', 'ChildPOSSet': 'P,V,Z', 'RightSiblingWord': 'Poljskoj', 'RightSiblingPos': 'N', 'RightSiblingFeats': 'N'}, {'PredWord': 'Vjeruje', 'PredPos': 'V', 'PredDeprel': 'ROOT', 'PredFets': 'V', 'ArgWord': 'u', 'ArgPos': 'S', 'ArgDeprel': 'CASE', 'ArgFets': 'S', 'DeprelPath': 'CSUBJ down NMOD down CASE down', 'PosPath': 'V down N down S down', 'Position': True, 'DepSubCat': 'ROOT,PUNCT,COMPOUND,CSUBJ', 'ChildDepSet': 'COMPOUND,CSUBJ,PUNCT', 'ChildWordSet': 'se,nalaze,.', 'ChildPOSSet': 'P,V,Z'}, {'PredWord': 'Vjeruje', 'PredPos': 'V', 'PredDeprel': 'ROOT', 'PredFets': 'V', 'ArgWord': 'Poljskoj', 'ArgPos': 'N', 'ArgDeprel': 'NMOD', 'ArgFets': 'N', 'DeprelPath': 'CSUBJ down NMOD down', 'PosPath': 'V down N down', 'Position': True, 'DepSubCat': 'ROOT,PUNCT,COMPOUND,CSUBJ', 'ChildDepSet': 'COMPOUND,CSUBJ,PUNCT', 'ChildWordSet': 'se,nalaze,.', 'ChildPOSSet': 'P,V,Z', 'LeftSiblingWord': 'se', 'LeftSiblingPos': 'P', 'LeftSiblingFeats': 'P', 'RightSiblingWord': 'pričuva', 'RightSiblingPos': 'N', 'RightSiblingFeats': 'N'}, {'PredWord': 'Vjeruje', 'PredPos': 'V', 'PredDeprel': 'ROOT', 'PredFets': 'V', 'ArgWord': 'nalaze', 'ArgPos': 'V', 'ArgDeprel': 'CSUBJ', 'ArgFets': 'V', 'DeprelPath': 'CSUBJ down', 'PosPath': 'V down', 'Position': True, 'DepSubCat': 'ROOT,PUNCT,COMPOUND,CSUBJ', 'ChildDepSet': 'COMPOUND,CSUBJ,PUNCT', 'ChildWordSet': 'se,nalaze,.', 'ChildPOSSet': 'P,V,Z', 'RightSiblingWord': '.', 'RightSiblingPos': 'Z', 'RightSiblingFeats': 'Z', 'LeftWord': 'da', 'LeftPos': 'C', 'LeftFeats': 'C', 'RightWord': 'pričuva', 'RightPos': 'N', 'RightFeats': 'pričuva'}, {'PredWord': 'Vjeruje', 'PredPos': 'V', 'PredDeprel': 'ROOT', 'PredFets': 'V', 'ArgWord': 'neke', 'ArgPos': 'P', 'ArgDeprel': 'AMOD', 'ArgFets': 'P', 'DeprelPath': 'CSUBJ down NSUBJ down AMOD down', 'PosPath': 'V down N down P down', 'Position': True, 'DepSubCat': 'ROOT,PUNCT,COMPOUND,CSUBJ', 'ChildDepSet': 'COMPOUND,CSUBJ,PUNCT', 'ChildWordSet': 'se,nalaze,.', 'ChildPOSSet': 'P,V,Z', 'RightSiblingWord': 'od', 'RightSiblingPos': 'S', 'RightSiblingFeats': 'S'}, {'PredWord': 'Vjeruje', 'PredPos': 'V', 'PredDeprel': 'ROOT', 'PredFets': 'V', 'ArgWord': 'od', 'ArgPos': 'S', 'ArgDeprel': 'CASE', 'ArgFets': 'S', 'DeprelPath': 'CSUBJ down NSUBJ down CASE down', 'PosPath': 'V down N down S down', 'Position': True, 'DepSubCat': 'ROOT,PUNCT,COMPOUND,CSUBJ', 'ChildDepSet': 'COMPOUND,CSUBJ,PUNCT', 'ChildWordSet': 'se,nalaze,.', 'ChildPOSSet': 'P,V,Z', 'RightSiblingWord': 'najvećih', 'RightSiblingPos': 'A', 'RightSiblingFeats': 'A'}, {'PredWord': 'Vjeruje', 'PredPos': 'V', 'PredDeprel': 'ROOT', 'PredFets': 'V', 'ArgWord': 'najvećih', 'ArgPos': 'A', 'ArgDeprel': 'AMOD', 'ArgFets': 'A', 'DeprelPath': 'CSUBJ down NSUBJ down AMOD down', 'PosPath': 'V down N down A down', 'Position': True,  ...

# %%
import sklearn_crfsuite
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=0.2009,
    c2=0.0284,
    max_iterations=100,
    all_possible_transitions=True
)

# %%
model = crf.fit(X_train, y_train)

# %%
y_pred = crf.predict(X_test)

# %%
import joblib
joblib.dump(crf, "ac.pkl")
# Out:
# ['ac.pkl']

# %%
from sklearn_crfsuite import metrics
labels = crf.classes_
labels.remove("_")
print(metrics.flat_classification_report(y_test, y_pred, digits=2, labels=labels))
# Out:
#               precision    recall  f1-score   support
#
#          ACT       0.90      0.94      0.92       962
#         MANN       0.57      0.53      0.55       100
#          PAT       0.80      0.81      0.80      1052
#          REG       0.50      0.32      0.39        47
#        PHRAS       0.17      0.08      0.11        12
#          REC       0.84      0.62      0.72       117
#        RESLT       0.82      0.82      0.82       562
#          LOC       0.45      0.61      0.52        97
#        MODAL       0.81      0.98      0.89       115
#         TIME       0.77      0.82      0.80       238
#         ORIG       0.64      0.58      0.61        64
#          DUR       0.78      0.49      0.60        88
#        CAUSE       0.82      0.26      0.40        53
#         FREQ       1.00      0.67      0.80        15
#       SOURCE       1.00      0.18      0.31        11
#          AIM       0.67      0.49      0.56        45
#        QUANT       0.79      0.53      0.64        43
#         COND       0.67      0.46      0.55        13
#        CONTR       0.71      0.36      0.48        14
#       MWPRED       0.93      0.37      0.53        35
#        MEANS       0.44      0.38      0.41        21
#        EVENT       0.74      0.54      0.62        26
#         ACMP       0.64      0.39      0.49        23
#         GOAL       0.54      0.16      0.25        43
#        RESTR       1.00      0.43      0.60         7
#
#    micro avg       0.80      0.77      0.79      3803
#    macro avg       0.72      0.51      0.57      3803
# weighted avg       0.80      0.77      0.78      3803

# %%
from collections import Counter
def print_state_features(state_features):
    for (attr, label), weight in state_features:
        print("%0.6f %-8s %s" % (weight, label, attr))

print("Top positive:")
print_state_features(Counter(crf.state_features_).most_common(300))

print("\nTop negative:")
print_state_features(Counter(crf.state_features_).most_common()[-300:])
# Out:
# Top positive:
# 7.657479 TIME     LeftWord:nakon
# 7.425624 _        ArgFets:Type=participle
# 7.030543 LOC      ArgFets:Type=proper|Gender=feminine|Number=singular|Case=locative
# 7.011836 CAUSE    LeftWord:zbog
# 6.914578 TIME     ArgWord:sada
# 6.817562 TIME     LeftWord:prije
# 6.699139 DUR      ArgWord:uvijek
# 6.684276 DUR      ArgWord:dalje
# 6.537859 _        RightSiblingWord:suverenitet
# 6.337272 RESTR    LeftWord:Osim
# 6.190760 PAT      DeprelPath:PARATAXIS up
# 6.184445 _        DeprelPath:AUXPASS down
# 6.180242 MEANS    LeftWord:kroz
# 6.142283 MANN     ArgWord:način
# 6.127979 PAT      DeprelPath:CSUBJPASS down COP down
# 5.952270 TIME     ArgWord:srijedu
# 5.932529 QUANT    ArgWord:Toliko
# 5.889607 RESLT    ArgWord:NATO-a
# 5.757063 TIME     ArgWord:ponedjeljak
# 5.747483 _        ArgWord:također
# 5.697885 _        PredPos:N
# 5.695911 DUR      ArgWord:dugo
# 5.673933 RESLT    DeprelPath:CSUBJPASS down COP down
# 5.641713 PAT      ArgWord:gubitaka
# 5.615423 TIME     ArgWord:utorak
# 5.591982 RESLT    ArgWord:Chevron
# 5.573179 TIME     ArgWord:četvrtak
# 5.569797 TIME     ArgWord:međuvremenu
# 5.569214 AIM      ArgWord:cilju
# 5.535430 LOC      PredParentWord:regulirano
# 5.503589 GOAL     PredWord:teže
# 5.482328 TIME     ArgWord:danas
# 5.388533 TIME     ArgWord:nedjelju
# 5.381241 REG      LeftWord:glede
# 5.374048 RESLT    DeprelPath:ROOT up AUXPASS down
# 5.323181 _        DeprelPath:COP down
# 5.321692 REC      ArgWord:SETimes
# 5.283592 PAT      DeprelPath:CSUBJ down COP down
# 5.275447 GOAL     ArgWord:smjeru
# 5.239623 REG      LeftWord:Prema
# 5.238785 REC      PredWord:podupire
# 5.237892 CONTR    LeftFeats:Case=dative
# 5.178301 FREQ     ArgWord:često
# 5.177492 DUR      ArgWord:godinu
# 5.168571 _        DeprelPath:AUX down
# 5.168569 ACMP     ArgFets:Type=proper|Gender=feminine|Number=singular|Case=instrumental
# 5.125815 TIME     LeftWord:Prije
# 5.109651 _        ArgWord:se
# 5.104495 PAT      ArgWord:Nikada
# 5.103065 TIME     LeftWord:Nakon
# 5.057905 FREQ     ArgWord:ponovno
# 5.046496 LOC      ArgFets:Type=proper|Gender=masculine|Number=singular|Case=locative
# 5.046210 CAUSE    ArgWord:razloga
# 5.036546 TIME     DeprelPath:AUXPASS up ADVMOD down
# 5.028137 TIME     ArgWord:konačno
# 5.014809 PAT      DeprelPath:XCOMP down ACL down NSUBJ down
# 5.010504 PAT      LeftWord:o
# 4.998988 MEANS    ArgFets:Type=common|Gender=masculine|Number=singular|Case=instrumental
# 4.902138 ACT      DeprelPath:NSUBJ down
# 4.893561 ORIG     LeftWord:od
# 4.873132 TIME     LeftWord:tijekom
# 4.867045 LOC      ArgWord:putu
# 4.860209 _        PredDeprel:ROOT
# 4.855632 QUANT    ArgWord:malo
# 4.838607 FREQ     ArgWord:put
# 4.835238 GOAL     ArgWord:naprijed
# 4.817123 FREQ     ArgWord:puta
# 4.798860 ACT      DeprelPath:NSUBJ down NMOD down
# 4.796642 _        ArgWord:već
# 4.792059 PAT      DeprelPath:ADVCL up
# 4.776716 ACT      ArgWord:potvrditi
# 4.759944 TIME     ArgWord:ranije
# 4.748960 _        RightSiblingWord:posljedica
# 4.745655 PHRAS    ArgWord:vidu
# 4.731089 LOC      ArgWord:ovdje
# 4.728265 _        ArgWord:jednaki
# 4.706603 TIME     ArgWord:godine
# 4.686630 GOAL     ArgWord:razinu
# 4.674114 REC      ArgWord:mladež
# 4.673891 TIME     ArgWord:Danas
# 4.667479 RESTR    LeftWord:osim
# 4.649857 TIME     PredParentWord:počišćeni
# 4.639271 ACT      ArgWord:krizom
# 4.620345 TIME     ArgWord:budućnosti
# 4.604142 RESLT    RightSiblingWord:konzultacija
# 4.603718 EVENT    ArgWord:skupu
# 4.598196 FREQ     ArgWord:svakodnevno
# 4.583978 RESLT    DeprelPath:ROOT up COP down
# 4.571057 RESLT    DeprelPath:CCOMP down COP down
# 4.566486 PHRAS    ArgWord:koštac
# 4.526003 EVENT    ArgWord:festivalu
# 4.521143 RESLT    PredWord:obećao
# 4.508972 RESLT    PosPath:A up
# 4.501090 TIME     ArgWord:petak
# 4.498721 PAT      ChildWordSet:,,je,dnevnik
# 4.463580 TIME     ArgWord:koncu
# 4.458801 MEANS    ArgFets:Type=common|Gender=neuter|Number=singular|Case=instrumental
# 4.446092 PAT      ArgWord:Nagrada
# 4.444079 _        PredPos:A
# 4.443524 PAT      ArgWord:otkrili
# 4.440033 CONTR    LeftWord:Iako
# 4.434776 TIME     ArgWord:nedavno
# 4.427642 DUR      ArgWord:još
# 4.395678 TIME     ArgWord:godini
# 4.388819 RESLT    PredWord:poziva
# 4.376582 MEANS    ArgWord:Time
# 4.368830 ACT      DeprelPath:NSUBJ down AMOD down
# 4.351540 TIME     ArgWord:vrijeme
# 4.338056 REC      ArgFets:Type=proper|Gender=masculine|Number=singular|Case=dative
# 4.311849 ORIG     ArgWord:priopćenju
# 4.304604 LOC      ArgFets:Type=proper|Gender=neuter|Number=singular|Case=locative
# 4.283042 TIME     ArgWord:trenutku
# 4.281126 PAT      ArgWord:politikom
# 4.272726 PHRAS    ArgWord:leđa
# 4.269797 RESLT    ArgWord:Broj
# 4.256100 PAT      ArgWord:carinska
# 4.238909 LOC      ArgWord:Ovdje
# 4.224510 ORIG     ArgWord:izvješću
# 4.224076 RESLT    ArgWord:suradnja
# 4.222325 QUANT    ArgWord:dolara
# 4.217768 TIME     PosPath:N down A down V down
# 4.215152 DUR      ArgWord:sada
# 4.205982 LOC      LeftWord:ispred
# 4.203937 _        ArgWord:tisuće
# 4.189901 ACT      DeprelPath:NSUBJPASS down
# 4.178667 QUANT    ArgWord:stotine
# 4.175009 LOC      ArgWord:svijetu
# 4.167341 _        ChildPOSSet:P,P,N,V
# 4.166819 _        ArgDeprel:PUNCT
# 4.163378 AIM      ArgWord:pokušaju
# 4.148928 EVENT    RightWord:natjecanja
# 4.144885 TIME     ArgWord:trenutačno
# 4.132219 _        ArgWord:Također
# 4.124748 TIME     ArgWord:odmah
# 4.107174 MODAL    PredWord:treba
# 4.104002 TIME     ArgWord:subotu
# 4.097827 _        ChildWordSet:pravilima,tvrtke,sudjelovati,.
# 4.086905 GOAL     ArgFets:Type=proper|Gender=masculine|Number=singular|Case=dative
# 4.082468 EVENT    ArgWord:zasjedanju
# 4.078828 MEANS    ArgFets:Type=common|Gender=feminine|Number=singular|Case=instrumental
# 4.069190 MEANS    ArgFets:Type=common|Gender=neuter|Number=plural|Case=instrumental
# 4.062111 PAT      RightSiblingWord:pokazuju
# 4.048942 RESLT    LeftWord:do
# 4.041835 _        DeprelPath:CONJ down
# 4.034977 EVENT    ArgWord:sastanku
# 4.032129 MODAL    DeprelPath:XCOMP down
# 4.024945 _        ArgDeprel:CASE
# 4.002867 CAUSE    ArgWord:zahvaljujući
# 3.998832 ORIG     PredParentWord:predviđeni
# 3.996148 TIME     ArgWord:kasnije
# 3.993937 TIME     ArgWord:izbora
# 3.980199 QUANT    ArgWord:najviše
# 3.976133 ORIG     LeftWord:iz
# 3.975708 EVENT    ArgWord:izborima
# 3.974804 ORIG     ArgWord:intervjuu
# 3.954117 RESLT    PredWord:postati
# 3.947306 DUR      ArgWord:godine
# 3.946470 RESLT    ArgWord:nemoguće
# 3.942131 GOAL     ArgFets:Type=proper|Gender=feminine|Number=singular|Case=accusative
# 3.916334 RESLT    DeprelPath:CCOMP down AUXPASS down
# 3.913281 _        ArgWord:samo
# 3.911773 TIME     ArgWord:tada
# 3.882853 LOC      ArgWord:zemlji
# 3.880563 MEANS    ArgFets:Type=common|Gender=feminine|Number=plural|Case=instrumental
# 3.867981 RESLT    PosPath:V up
# 3.866825 _        LeftWord:Šest
# 3.853654 PAT      ArgWord:Gora
# 3.839266 ACT      ArgWord:Regionalna
# 3.839223 ACT      ArgWord:gospodarske
# 3.832214 ACT      ArgWord:Zemlji
# 3.831466 PAT      ArgWord:dosegnula
# 3.827911 DUR      ArgWord:godina
# 3.819976 _        RightSiblingWord:vođu
# 3.814500 ACT      DeprelPath:NSUBJ down NUMMOD down
# 3.807408 PAT      DeprelPath:ACL up NSUBJPASS down
# 3.801649 RESLT    PredWord:ispregovarati
# 3.799099 RESLT    DeprelPath:ROOT up AMOD down
# 3.794220 DUR      DeprelPath:CONJ up NMOD down NMOD down
# 3.793542 GOAL     RightSiblingWord:način
# 3.785421 MANN     ArgWord:službeno
# 3.774718 LOC      PredWord:nalazi
# 3.768008 PAT      LeftFeats:Type=possessive|Person=third|Gender=neuter|Number=singular|Case=nominative
# 3.756840 PAT      ArgWord:Pokrovitelji
# 3.755502 PAT      DeprelPath:CCOMP down COP down
# 3.751381 _        ArgWord:snimatelja
# 3.747340 _        RightWord:granica
# 3.745607 REC      PredWord:pomoći
# 3.743934 LOC      ArgWord:premijera
# 3.728585 REC      ArgFets:Type=common|Gender=neuter|Number=plural|Case=dative
# 3.728467 PAT      ArgWord:uvjeta
# 3.727622 REG      LeftWord:oko
# 3.725233 RESLT    LeftWord:kao
# 3.717536 EVENT    ArgWord:konferenciji
# 3.712570 TIME     ArgWord:lipnju
# 3.711996 TIME     PredParentWord:ušutkana
# 3.709947 ACMP     PredWord:surađivati
# 3.707108 _        RightSiblingWord:RS
# 3.694542 REG      ChildPOSSet:Z,P,V,N,V,N
# 3.693613 DUR      LeftWord:dok
# 3.689482 RESLT    PredWord:ostati
# 3.671165 MEANS    ArgFets:Type=common|Gender=masculine|Number=plural|Case=instrumental
# 3.664071 MODAL    PredWord:mora
# 3.661255 TIME     LeftWord:Tijekom
# 3.652910 DUR      ArgWord:dana
# 3.633481 ACT      LeftSiblingWord:nemoguće
# 3.626273 MWPRED   PredWord:planiraju
# 3.619644 ACT      PosPath:P down A down V down
# 3.612937 ACT      RightSiblingWord:nogometni
# 3.605913 PAT      PosPath:Z down P down
# 3.595353 TIME     ArgWord:dan
# 3.593208 _        RightSiblingWord:obuku
# 3.593139 AIM      LeftWord:kako
# 3.586991 QUANT    ArgWord:mjeri
# 3.584627 MANN     ArgWord:cijelosti
# 3.575300 PAT      PredWord:zadužen
# 3.575029 MODAL    DeprelPath:XCOMP down AUXPASS down
# 3.573426 MANN     DeprelPath:AMOD down
# 3.573326 DUR      ArgWord:razdoblju
# 3.572229 MWPRED   PredWord:planira
# 3.568563 CONTR    PosPath:N up R down V down
# 3.563981 GOAL     LeftWord:do
# 3.563297 RESLT    ArgWord:mjestu
# 3.561613 MANN     PredParentWord:obvezatan
# 3.557527 ACMP     PredWord:sastao
# 3.552176 REC      LeftSiblingWord:pritisak
# 3.546562 REC      ArgFets:Type=personal|Person=third|Gender=masculine|Number=singular|Case=dative
# 3.546257 PHRAS    PredWord:nalaze
# 3.541018 PAT      PosPath:N up
# 3.534757 _        DeprelPath:NSUBJPASS up
# 3.534159 RESLT    ArgWord:konsenzusa
# 3.517884 ACT      RightSiblingWord:cilj
# 3.512752 COND     LeftWord:ako
# 3.506884 RESLT    DeprelPath:CSUBJ down AUXPASS down
# 3.506623 RESLT    ArgWord:posjetu
# 3.498219 SOURCE   LeftWord:s
# 3.497995 QUANT    ArgWord:posto
# 3.493798 ACT      PosPath:N down P down
# 3.481076 AIM      PredWord:usmjereni
# 3.478788 ACT      DeprelPath:NSUBJ down ACL down COP down
# 3.478411 EVENT    PredWord:nazočili
# 3.477360 ORIG     ArgWord:rezoluciji
# 3.476778 SOURCE   LeftWord:iz
# 3.476500 MWPRED   PredWord:nastaviti
# 3.473094 TIME     ArgWord:kraju
# 3.468757 _        ArgWord:Smatram
# 3.468033 PAT      DeprelPath:DOBJ down
# 3.467905 ORIG     PredParentWord:opisana
# 3.463294 GOAL     ArgWord:gol
# 3.462446 RESLT    RightSiblingWord:dovela
# 3.461704 QUANT    PredParentWord:potraćene
# 3.456232 ORIG     ArgWord:izjavi
# 3.453911 _        PredPos:R
# 3.451607 RESLT    RightWord:Europi
# 3.449398 REC      ArgWord:Građani
# 3.446334 RESLT    RightSiblingWord:prvo
# 3.444046 MANN     ArgWord:dobro
# 3.439063 _        RightWord:posjetiteljima
# 3.438964 AIM      ArgWord:potrazi
# 3.432628 REC      PredWord:dobilo
# 3.432388 RESLT    PredWord:kaže
# 3.423722 ORIG     ArgWord:temelju
# 3.423428 RESLT    RightSiblingWord:Jelena
# 3.417593 CAUSE    ArgWord:znak
# 3.395597 RESLT    DeprelPath:ADVCL up
# 3.395581 _        RightSiblingWord:odstupiti
# 3.394469 MEANS    LeftWord:preko
# 3.385867 GOAL     ArgWord:NATO-u
# 3.385618 LOC      ArgWord:kod
# 3.384491 _        RightSiblingWord:posjetu
# 3.379159 ACT      ArgWord:Obitelji
# 3.378677 PAT      RightSiblingWord:stopa
# 3.368676 PAT      ArgWord:ubrzao
# 3.364002 TIME     ArgWord:doba
# 3.363542 DUR      PredWord:trajao
# 3.356985 CONTR    ArgFets:Type=common|Gender=masculine|Number=singular|Case=dative
# 3.354066 COND     LeftWord:ukoliko
# 3.350107 EVENT    PredWord:sudjelovati
# 3.348235 TIME     ChildWordSet:otvorena
# 3.341340 PAT      PosPath:A up P down V down
# 3.335582 ORIG     ArgFets:Type=proper|Gender=masculine|Number=singular|Case=genitive
# 3.333091 ACT      RightSiblingWord:kultura
# 3.332776 _        ArgWord:političara
# 3.325098 ACT      PredParentWord:poduzet
# 3.324592 ORIG     PredParentWord:ukazano
# 3.319517 TIME     PredParentWord:podignuta
# 3.319401 PAT      PredWord:posvećen
# 3.311579 ACT      PosPath:A down
# 3.310965 TIME     ArgWord:Trenutačno
# 3.309006 PAT      ArgWord:Predmet
# 3.299792 MANN     LeftWord:po
# 3.299242 _        RightWord:poslodavaca
# 3.293556 MANN     PredParentWord:kritiziran
# 3.290811 ACT      PosPath:R up N down V down
# 3.288864 RESLT    ArgWord:situaciji
# 3.281843 ACT      ArgWord:dužnost
# 3.277789 QUANT    ArgWord:metara
# 3.274710 EVENT    ArgWord:posjet
# 3.274547 REC      PredWord:pozvao
# 3.273069 RESLT    ArgWord:važnosti
# 3.272398 RESLT    DeprelPath:XCOMP down
#
# Top negative:
# -1.619359 _        ArgWord:poziva
# -1.619821 AIM      PredDeprel:COP
# -1.622101 PAT      PredParentWord:Vrijeme
# -1.622915 _        PosPath:S down
# -1.624586 ACT      ArgWord:sastanak
# -1.630525 REG      DepSubCat:PUNCT,NMOD,NSUBJ,ROOT,XCOMP
# -1.633903 _        RightWord:napada
# -1.634117 PAT      ChildDepSet:DOBJ,CCOMP
# -1.637632 _        PredWord:odobriti
# -1.641769 _        DeprelPath:APPOS up COMPOUND down
# -1.645734 _        LeftSiblingWord:vlast
# -1.652442 _        RightSiblingWord:albanska
# -1.652669 RESLT    PredDeprel:CCOMP
# -1.653898 RESLT    LeftSiblingFeats:Type=common|Gender=neuter|Number=singular|Case=genitive
# -1.656560 PAT      LeftFeats:Type=indefinite|Gender=masculine|Number=plural|Case=nominative
# -1.659726 ACT      PredParentFeats:Type=participle|Degree=positive|Gender=masculine|Number=singular|Case=nominative|Definiteness=no
# -1.662641 PAT      RightWord:ubojstvo
# -1.667197 _        DeprelPath:NSUBJPASS down NMOD down
# -1.668703 ACT      ArgWord:cijene
# -1.669202 _        ChildWordSet:znanje
# -1.669702 DUR      LeftSiblingFeats:Type=common|Gender=masculine|Number=singular|Case=genitive
# -1.673261 _        PredWord:posjećivati
# -1.673261 _        PredParentWord:počelo
# -1.676119 GOAL     LeftWord:za
# -1.678630 _        DeprelPath:CONJ up NMOD down NMOD down
# -1.679797 ACT      PredWord:dobit
# -1.681115 _        PredWord:izrečena
# -1.681732 REG      ChildDepSet:NMOD,NSUBJ,DOBJ,PUNCT
# -1.682195 PAT      RightWord:reformi
# -1.683855 _        RightSiblingWord:ubijeni
# -1.684008 ACT      ArgWord:Broj
# -1.691926 _        ArgWord:počinitelje
# -1.708089 ACT      PredWord:vidi
# -1.709418 ACT      ChildDepSet:NMOD,NSUBJ,AUX,CCOMP,PUNCT
# -1.711587 ACT      PredParentWord:Vjetrovi
# -1.712044 ACT      ChildPOSSet:Z,P,V,N,N,N
# -1.712271 _        ArgWord:odbio
# -1.714188 _        RightSiblingWord:ovoj
# -1.718977 GOAL     ArgFets:Type=common|Gender=masculine|Number=singular|Case=genitive
# -1.718990 _        ArgWord:trajanja
# -1.726004 ACT      PredParentWord:istaknuo
# -1.728417 ACT      PredParentFeats:Type=common|Gender=masculine|Number=singular|Case=accusative|Animate=no
# -1.729193 PAT      ArgWord:žrtve
# -1.729933 PAT      LeftSiblingFeats:Type=common|Gender=neuter|Number=singular|Case=accusative
# -1.730172 _        PosPath:A up P down
# -1.731215 PAT      PredPos:A
# -1.731982 ACT      ArgFets:Type=indefinite|Person=third|Gender=neuter|Case=nominative
# -1.734142 _        PredParentWord:gladni
# -1.736485 PAT      ArgWord:političara
# -1.749166 _        RightWord:vlast
# -1.751210 ACT      ChildPOSSet:N,R,V,V,N,Z
# -1.754727 _        ArgWord:kritičar
# -1.756702 PAT      ArgFets:Type=common|Gender=masculine|Number=plural|Case=dative
# -1.761448 _        PredParentWord:pozornošću
# -1.763683 _        ArgWord:dozvoljeni
# -1.763956 ACT      DepSubCat:NSUBJ,PUNCT,COMPOUND,ROOT,NMOD
# -1.774553 MODAL    PredDeprel:XCOMP
# -1.776803 RESLT    ArgWord:priznata
# -1.777859 PAT      PredWord:izjavio
# -1.779601 _        PosPath:A up V down
# -1.784850 PAT      PredParentWord:dohvat
# -1.786622 _        LeftSiblingFeats:Type=common|Gender=masculine|Number=singular|Case=accusative|Animate=yes
# -1.788451 RESLT    ChildDepSet:PUNCT,AUX,NSUBJ,PUNCT
# -1.791174 PAT      ArgDeprel:ADVCL
# -1.792610 _        DeprelPath:ROOT up ADVMOD down
# -1.796330 _        PosPath:N up P down V down
# -1.798706 _        DeprelPath:ADVCL up NSUBJPASS down
# -1.804899 RESLT    RightFeats:Type=common|Gender=neuter|Number=singular|Case=nominative
# -1.805181 PAT      ArgWord:razinu
# -1.806801 PAT      ArgFets:Type=common|Gender=masculine|Number=singular|Case=dative
# -1.808710 _        DeprelPath:NMOD down NMOD down CASE down
# -1.809230 _        ArgWord:Zakon
# -1.810679 RESLT    ArgFets:Type=general|Degree=superlative|Gender=feminine|Number=plural|Case=genitive|Definiteness=yes
# -1.814944 _        PosPath:R up P down
# -1.816776 _        LeftSiblingWord:broj
# -1.817614 _        PosPath:N up R down
# -1.817719 _        PosPath:N up A down M down
# -1.820718 _        PosPath:V down V down
# -1.825144 _        PredDeprel:COMPOUND
# -1.828026 ACT      ArgFets:Type=common|Gender=feminine|Number=singular|Case=accusative
# -1.831561 _        RightWord:oporbene
# -1.831890 TIME     PredParentFeats:Type=common|Gender=masculine|Number=plural|Case=accusative
# -1.836767 PAT      ArgWord:mogu
# -1.836870 _        LeftSiblingWord:izvješća
# -1.836905 _        ArgWord:održana
# -1.839747 REC      ArgFets:Type=common|Gender=masculine|Number=singular|Case=genitive
# -1.851447 _        LeftWord:nove
# -1.851455 _        PosPath:M up
# -1.852056 PAT      ArgWord:gospodarstvo
# -1.853627 _        RightSiblingWord:borba
# -1.856176 RESLT    ArgWord:najsigurnijih
# -1.871389 _        DeprelPath:CSUBJPASS up
# -1.871593 _        LeftWord:luke
# -1.876850 _        LeftSiblingWord:režim
# -1.876908 ACT      PredWord:morali
# -1.883507 ACT      DepSubCat:NSUBJ,CONJ,AUX,DOBJ
# -1.884501 TIME     RightWord:života
# -1.890758 _        ArgWord:stadionu
# -1.896394 RESLT    PredParentWord:usamljen
# -1.904534 _        RightSiblingWord:Međunarodnim
# -1.908555 _        ArgWord:rezolucije
# -1.910866 MWPRED   PredPos:V
# -1.915038 _        PredParentWord:otpušteno
# -1.916642 _        PredWord:podnijet
# -1.916642 _        ChildWordSet:država,će,stajališta,petka,.
# -1.916743 _        DeprelPath:CCOMP up NSUBJ down NUMMOD down REMNANT down
# -1.917847 _        PosPath:A up P up
# -1.920155 _        LeftSiblingWord:UN-ovom
# -1.924168 TIME     PredFets:Type=main|VForm=participle|Number=plural|Gender=neuter
# -1.935588 PAT      ChildDepSet:PUNCT,NMOD,DOBJ
# -1.936041 _        RightSiblingWord:situacija
# -1.938411 TIME     PredParentFeats:Type=common|Gender=neuter|Number=singular|Case=nominative
# -1.944012 ACT      ArgWord:godina
# -1.946631 _        ArgWord:ideja
# -1.946874 RESLT    LeftSiblingFeats:Type=auxiliary|VForm=present|Person=first|Number=plural
# -1.951269 PAT      ArgDeprel:NMOD
# -1.952500 _        DeprelPath:DISCOURSE down
# -1.952528 _        ChildDepSet:NSUBJ,AUX,NMOD,PUNCT
# -1.956647 ACT      PredWord:moraju
# -1.965713 _        ChildWordSet:vlasništvo,sustavu
# -1.966694 ACT      PredWord:potvrditi
# -1.967555 ACT      ArgWord:situacija
# -1.976984 RESLT    RightSiblingFeats:Type=proper|Gender=masculine|Number=singular|Case=nominative
# -1.977227 ACT      PredWord:smatra
# -1.980065 ACT      PredParentWord:Želimo
# -1.989894 _        ArgWord:Rumunjske
# -1.994256 _        PosPath:R up V down
# -1.998892 _        RightWord:sveučilištima
# -2.005115 _        RightSiblingWord:komemoracijske
# -2.008586 _        DeprelPath:CCOMP down DOBJ down ACL down
# -2.009362 _        RightWord:razloga
# -2.010428 _        LeftSiblingWord:pregovora
# -2.013415 PAT      PredParentWord:dozvoljen
# -2.014263 PAT      PredParentPos:M
# -2.014792 _        RightSiblingWord:preseljenje
# -2.016523 ACT      PredWord:dobila
# -2.020007 _        RightSiblingWord:riješiti
# -2.022057 _        ArgWord:tko
# -2.023720 PAT      PredWord:kazao
# -2.023806 _        DeprelPath:NSUBJ down NUMMOD down
# -2.031928 _        LeftSiblingWord:kritičari
# -2.040102 ACT      PredWord:otvara
# -2.041124 _        DeprelPath:DOBJ down NMOD down
# -2.041180 _        RightWord:prenosi
# -2.044529 _        PosPath:N up V down
# -2.044586 _        ArgWord:proizvodnje
# -2.045220 _        ArgWord:siječanj
# -2.049317 _        DeprelPath:NMOD down ADVMOD down
# -2.050059 ACT      ArgFets:Type=common|Gender=masculine|Number=singular|Case=locative
# -2.059328 _        DeprelPath:CONJ up ADVMOD down
# -2.074979 _        ArgWord:svemu
# -2.076186 ACT      ArgDeprel:ADVMOD
# -2.107764 _        LeftSiblingWord:obično
# -2.110870 _        DeprelPath:DOBJ down NSUBJ down
# -2.111210 ACT      LeftFeats:Form=letter|Type=ordinal|Gender=feminine|Number=singular|Case=nominative
# -2.113113 _        PosPath:V up V up N down
# -2.124244 _        PosPath:P up
# -2.129739 _        RightSiblingWord:načelo
# -2.147412 PAT      ArgFets:Type=proper|Gender=feminine|Number=singular|Case=dative
# -2.147833 RESLT    LeftSiblingPos:S
# -2.150937 _        ArgWord:glasovanja
# -2.153988 _        PosPath:V up N up N up
# -2.168024 CAUSE    PredFets:Type=participle|Degree=positive|Gender=neuter|Number=singular|Case=nominative|Definiteness=yes
# -2.171545 _        ArgWord:zahvaljujući
# -2.175962 TIME     PredParentFeats:Type=participle|Degree=positive|Gender=neuter|Number=singular|Case=nominative|Definiteness=yes
# -2.184435 _        DeprelPath:ADVMOD down NMOD down
# -2.185806 _        PredWord:riješiti
# -2.196093 _        ArgWord:politikom
# -2.205790 _        ArgWord:Branislav
# -2.207202 _        PosPath:R up N down
# -2.212384 _        PosPath:A down N down V down
# -2.215961 _        RightSiblingWord:znatno
# -2.222820 PAT      ArgFets:Type=common|Gender=neuter|Number=singular|Case=dative
# -2.224296 _        DeprelPath:NSUBJ down CONJ down APPOS down
# -2.230883 _        PredParentWord:zabranjena
# -2.239499 _        PosPath:C down
# -2.240560 _        PosPath:V up N down M down M down
# -2.242333 ACT      RightWord:Vojislav
# -2.256755 PAT      PredParentWord:dodana
# -2.261350 _        DeprelPath:ROOT up NSUBJ down
# -2.272617 _        DeprelPath:NMOD down AMOD down REMNANT down
# -2.290601 PAT      ArgFets:Type=common|Gender=feminine|Number=plural|Case=dative
# -2.291643 _        ArgWord:Belena
# -2.295320 PAT      PredParentWord:plan
# -2.316929 ACT      PredWord:opao
# -2.330394 _        PosPath:N down A down
# -2.333348 PAT      PredParentWord:Ključno
# -2.334554 _        ArgWord:Sporazumom
# -2.347787 _        PredParentWord:Žao
# -2.349835 _        RightSiblingWord:čin
# -2.354450 _        DeprelPath:XCOMP up ROOT up DOBJ down
# -2.358649 ACT      LeftWord:jedini
# -2.359449 ACT      ChildPOSSet:N,N,V,N,N,V,Z
# -2.372975 _        DeprelPath:XCOMP down XCOMP down NSUBJPASS down
# -2.376581 _        PosPath:A up M down
# -2.385064 PAT      DeprelPath:ADVCL down
# -2.389013 _        PosPath:R up
# -2.390209 _        DeprelPath:COMPOUND down
# -2.403010 RESLT    LeftSiblingFeats:Type=proper|Gender=masculine|Number=singular|Case=nominative
# -2.403708 _        PosPath:P up N down
# -2.425156 _        DeprelPath:XCOMP down NSUBJPASS down
# -2.432209 ACT      PredWord:dobio
# -2.437488 PAT      ChildPOSSet:V,Q,N,N
# -2.442107 _        DeprelPath:NSUBJ down ACL down COP down
# -2.452898 _        PosPath:A down
# -2.466678 PAT      ArgWord:dužnost
# -2.468447 _        ArgWord:članstva
# -2.489922 _        PosPath:N up P down
# -2.492170 _        RightSiblingWord:petogodišnjeg
# -2.502717 _        DeprelPath:CCOMP down CC down
# -2.504449 ACT      ArgWord:razina
# -2.506772 _        RightSiblingWord:uspjeti
# -2.514466 _        ArgWord:jedući
# -2.519290 _        DeprelPath:CCOMP up NSUBJPASS down
# -2.528984 _        PredParentWord:obilježeno
# -2.533739 _        DeprelPath:CSUBJPASS up NSUBJ down
# -2.561652 _        ArgWord:informiranja
# -2.575403 _        RightSiblingWord:pregovora
# -2.575948 _        DeprelPath:XCOMP down NMOD down
# -2.613107 _        DeprelPath:CSUBJ up NSUBJ down
# -2.632230 PAT      ArgDeprel:ADVMOD
# -2.640224 ACT      DepSubCat:NSUBJ,ROOT,PUNCT,NMOD
# -2.641777 ACT      ChildDepSet:COMPOUND,NSUBJ,NMOD
# -2.656857 ACT      DepSubCat:NSUBJ,ROOT,AUX,NMOD,PUNCT
# -2.669013 _        ArgWord:član
# -2.678965 _        ArgWord:gospodarske
# -2.695475 _        DeprelPath:CCOMP up DOBJ down
# -2.697607 RESLT    PredParentWord:lažirano
# -2.725458 _        DeprelPath:ROOT up NSUBJPASS down
# -2.748416 PAT      ArgWord:milijarde
# -2.752972 PAT      ArgDeprel:PARATAXIS
# -2.762303 _        RightWord:državama
# -2.764336 _        ArgWord:pritužbi
# -2.767381 _        DeprelPath:ROOT up AUXPASS down
# -2.781344 _        DeprelPath:ROOT up COP down
# -2.801615 _        PosPath:A up
# -2.816791 _        DeprelPath:ADVCL down COP down
# -2.871347 _        ArgWord:ekologe
# -2.878571 _        PosPath:A up N down
# -2.889584 _        ChildWordSet:premijer,je,tvornicu,.
# -2.896890 _        ArgWord:uvjeta
# -2.905381 _        RightSiblingWord:napora
# -2.921523 _        DeprelPath:CONJ up NSUBJPASS down
# -2.926285 ACT      PredWord:mogli
# -2.959381 _        ArgWord:siromaštva
# -2.993188 RESLT    RightWord:posto
# -2.998044 _        DeprelPath:ADVCL down AUXPASS down
# -3.055266 _        PosPath:N up N down
# -3.073894 _        ChildWordSet:obvezatno
# -3.087048 REC      LeftFeats:Case=locative
# -3.091059 _        ArgWord:kod
# -3.095627 _        DeprelPath:CCOMP up
# -3.144746 _        PosPath:N down N down
# -3.152213 _        LeftSiblingWord:Bit
# -3.164210 PAT      ChildDepSet:MARK,NSUBJ,DOBJ,XCOMP
# -3.202116 _        DeprelPath:ADVCL up NSUBJ down
# -3.239731 _        RightSiblingWord:dovela
# -3.335979 RESLT    PredWord:pokazuju
# -3.354260 _        DeprelPath:ACL up NSUBJ down
# -3.383939 _        ArgWord:carinska
# -3.415168 _        PosPath:X down
# -3.418120 _        PosPath:R down
# -3.488902 _        PosPath:P down A down V down
# -3.502002 _        DeprelPath:PARATAXIS up NSUBJ down
# -3.514850 _        PosPath:R down V down
# -3.558509 PAT      LeftSiblingWord:Hrvatska
# -3.704156 _        DeprelPath:AMOD down
# -3.802693 _        DeprelPath:ACL up
# -3.821119 _        PosPath:P down V down
# -3.830261 _        DeprelPath:CCOMP up NSUBJ down
# -3.854280 _        DeprelPath:CCOMP down COP down
# -3.877746 _        DeprelPath:CONJ up NSUBJ down
# -3.988018 _        ArgWord:Regionalna
# -4.009922 MODAL    PredPos:A
# -4.029801 _        DeprelPath:ACL down
# -4.030327 _        PosPath:N down V down
# -4.047546 _        PosPath:P down
# -4.133277 _        PosPath:A down V down
# -4.181094 _        DeprelPath:CCOMP down AUX down
# -4.265163 _        PosPath:A down A down
# -4.341586 _        DeprelPath:IOBJ down
# -4.353690 _        DeprelPath:CCOMP down AUXPASS down
# -4.444404 _        DeprelPath:ADVCL down MARK down
# -4.494603 _        PosPath:M down
# -4.657182 _        PosPath:N up
# -4.725515 _        ArgWord:gubitaka
# -4.784750 _        DeprelPath:PARATAXIS up
# -4.938214 _        DeprelPath:NSUBJ down
# -4.958958 _        DeprelPath:CONJ up
# -5.012598 _        DeprelPath:ADVCL up DOBJ down
# -5.267222 ACT      PredPos:A
# -5.315097 _        DeprelPath:NUMMOD down
# -5.370350 _        PosPath:A down P down V down
# -5.682099 _        DeprelPath:ADVMOD down
# -6.039098 _        PosPath:N down
# -6.553987 _        DeprelPath:DOBJ down
# -6.857374 _        DeprelPath:XCOMP down NSUBJ down
# -7.126237 _        DeprelPath:NMOD down
# -7.760724 _        DeprelPath:XCOMP down
# -7.913801 _        PosPath:V down

# %%
def custom_flatten (X, y):
    data = [feature for sentence in X for feature in sentence]
    labels = [label for sentence in y for label in sentence]
    return data, labels

train_data, train_labels = custom_flatten (X_train, y_train)
test_data, test_labels = custom_flatten (X_test, y_test)

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression
#from sklearn.svm import LinearSVC

vec = DictVectorizer(sparse=True)
enc = preprocessing.LabelEncoder()

clf = LogisticRegression(solver='liblinear')

X = vec.fit_transform(train_data)
y = enc.fit_transform(train_labels)
clf.fit(X,y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
test_data = vec.transform(test_data)
pred_labels = clf.predict(test_data)
pred_labels = enc.inverse_transform(pred_labels)
# Out:
# /home/daniel/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
from sklearn.metrics import classification_report
labels = list(enc.classes_)
labels.remove("_")

filtered = []
filtered_pred = []

for idx, label in enumerate(test_labels):
    if label != "_":
        filtered.append (label)
        filtered_pred.append(pred_labels[idx])
print(classification_report(filtered, filtered_pred, target_names=labels, digits=2))
# Out:
#              precision    recall  f1-score   support
#
#        ACMP       0.73      0.48      0.58        23
#         ACT       0.91      0.95      0.93       962
#         AIM       0.64      0.20      0.31        45
#       CAUSE       0.40      0.08      0.13        53
#        COND       0.60      0.23      0.33        13
#       CONTR       0.67      0.14      0.24        14
#         DUR       0.71      0.27      0.39        88
#       EVENT       0.59      0.50      0.54        26
#        FREQ       1.00      0.33      0.50        15
#        GOAL       0.62      0.19      0.29        43
#         LOC       0.52      0.62      0.57        97
#        MANN       0.60      0.43      0.50       100
#       MEANS       0.44      0.57      0.50        21
#       MODAL       0.80      0.98      0.88       115
#      MWPRED       0.91      0.29      0.43        35
#        ORIG       0.75      0.42      0.54        64
#         PAT       0.82      0.79      0.80      1052
#       PHRAS       0.00      0.00      0.00        12
#       QUANT       0.88      0.33      0.47        43
#         REC       0.93      0.64      0.76       117
#         REG       0.42      0.23      0.30        47
#       RESLT       0.84      0.78      0.81       562
#       RESTR       0.00      0.00      0.00         7
#      SOURCE       1.00      0.09      0.17        11
#        TIME       0.61      0.76      0.68       238
#
# avg / total       0.80      0.74      0.75      3803
# /home/daniel/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1428: UserWarning: labels size, 26, does not match size of target_names, 25
#   .format(len(labels), len(target_names))
# /home/daniel/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/daniel/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
