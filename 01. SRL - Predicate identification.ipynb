# %%
EOL = "\n"
SEP = "\t"
ETY = ""

# %%
def generate_featuresets (annotations):
    def get_parent(word, sentence):
        for item in sentence:
            if item[0] == word[8]:
                return item
        return []
        
    def get_children(word, sentence):
         for item in sentence:
            if item[8] == word[0]:
                yield item
    
    def feats_to_dict (feature):
        dict = {
            "Type": "",
            "Degree" : "",
            "Gender": "",
            "Number": "",
            "Case": "",
            "Definiteness": "", 
            "VForm": "",
            "Person": ""
        }
        for item in feature.split("|"):
            if "=" in item:
                label, value = item.split("=")
                dict[label] = value
        return dict
    
    for sentence in annotations:
        sentence_length = len(sentence)
        featuresets = []
        labels = []
        for word in sentence:
            word_feats = feats_to_dict(word[6])
            
            featureset = {
                'BOS': False,
                'EOS': False,
                'PredWord': word[2].lower(),
                'PredPos': word[4],
                'PredDeprel': word[10],
                'PredType': word_feats['Type'],
                'PredDegree': word_feats['Degree'],
                'PredGender': word_feats['Gender'],
                'PredNumber': word_feats['Number'],
                'PredCase': word_feats['Case'],
                'PredDefiniteness': word_feats['Definiteness'],
                'PredVForm': word_feats['VForm'],
                'PredPerson': word_feats['Person'],
                #'PredFeats': word[6],
                #'PredParentWord': "",
                #'PredParentPos': "",
                #'PredParentFeats': "",
                #'DepSubCat': "",
                #'ChildDepSet': "",
                #'ChildWordSet': "",
                #'ChildPOSSet': ""
            }
            
            if int(word[0]) == 1:
                featureset['BOS'] = True
            if int(word[0]) == sentence_length:
                featureset['EOS'] = True
            parent_word = get_parent(word, sentence)
            
            if len(parent_word) > 0:
                
                parent_feats = feats_to_dict(parent_word[6])
                
                featureset['PredParentWord'] = parent_word[2]
                featureset['PredParentPos'] = parent_word[4]
                featureset['PredParentFeats'] = parent_word[6]
                
                featureset['PredParentType']= parent_feats['Type']
                featureset['PredParentDegree'] =parent_feats['Degree']
                featureset['PredParentGender'] = parent_feats['Gender']
                featureset['PredParentNumber'] = parent_feats['Number']
                featureset['PredParentCase'] = parent_feats['Case']
                featureset['PredParentDefiniteness'] = parent_feats['Definiteness']
                featureset['PredParentVForm'] = parent_feats['VForm']
                featureset['PredParentPerson'] = parent_feats['Person']
                featureset['PredParentDeprel'] = parent_word[10] 
                
                
            children_words = list(get_children(word, sentence))
            if len(children_words)>0:
                DepSubChildren = [word]
                DepSubChildren.extend(children_words)
                
                DepSubChildren = sorted(DepSubChildren, key=lambda x: x[0], reverse=True)
                DepSubCat = ','.join([word[10] for word in DepSubChildren])
                ChildDepSet = ','.join([word[10] for word in children_words])
                ChildWordSet = ','.join([word[2] for word in children_words])
                ChildPOSSet = ','.join([word[4] for word in children_words])
                ChildCaseSet = ','.join([feats_to_dict(word[6])['Case'] for word in children_words])
                ChildTypeSet = ','.join([feats_to_dict(word[6])['Type'] for word in children_words])
                
                featureset['DepSubCat'] = DepSubCat
                featureset['ChildDepSet'] = ChildDepSet
                featureset['ChildWordSet'] = ChildWordSet
                featureset['ChildPOSSet'] = ChildPOSSet
                featureset['ChildCaseSet'] = ChildCaseSet
                featureset['ChildTypeSet'] = ChildTypeSet
            featuresets.append (featureset)
            labels.append("Y" if word[13] != "_"  else "_")
        yield featuresets, labels

# %%
file = open("data/hr.train.plus","r")
annotations = []
annotation = []
i = 0
for line in file:
    parts = line.replace(EOL, ETY).split(SEP)
    if len(parts) > 1:
        annotation.append(parts)
    else:
        annotations.append(annotation)
        annotation = []
    i = i + 1 
print ((i))
X_train, y_train = zip(*list(generate_featuresets(annotations)))
# Out:
# 69998

# %%
file = open("data/hr.test.plus","r")
test_annotations = []
test_annotation = []
j = 0
for line in file:
    parts = line.replace(EOL, ETY).split(SEP)
    if len(parts) > 1:
        test_annotation.append(parts)
    else:
        test_annotations.append(test_annotation)
        test_annotation = []
    j = j + 1
print (j)
X_test, y_test = zip(*list(generate_featuresets(test_annotations)))
# Out:
# 17389

# %%
import sklearn_crfsuite

crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=0.2009,
    c2=0.0284,
    max_iterations=100,
    all_possible_transitions=True,
    all_possible_states = True
)

model = crf.fit(X_train, y_train)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn_crfsuite import metrics
labels = list(model.classes_)
print(metrics.flat_classification_report(y_test, y_pred, digits=4, labels=labels))
# Out:
#               precision    recall  f1-score   support
#
#            _     0.9958    0.9948    0.9953     14614
#            Y     0.9627    0.9698    0.9662      2021
#
#     accuracy                         0.9918     16635
#    macro avg     0.9792    0.9823    0.9808     16635
# weighted avg     0.9918    0.9918    0.9918     16635

# %%
from collections import Counter
def print_state_features(state_features):
    for (attr, label), weight in state_features:
        print("%0.6f %-8s %s" % (weight, label, attr))

print("Top positive:")
print_state_features(Counter(crf.state_features_).most_common(300))

print("\nTop negative:")
print_state_features(Counter(crf.state_features_).most_common()[-300:])
# Out:
# Top positive:
# 4.289948 Y        PredWord:podrijetlo
# 3.282619 _        ChildDepSet:MARK,COMPOUND
# 3.248193 Y        PredWord:spreman
# 3.178922 Y        PredWord:zainteresiran
# 3.055432 Y        PredWord:zaključivanje
# 2.923477 _        ChildDepSet:MARK
# 2.865765 _        PredParentWord:dirnuti
# 2.841478 Y        PredWord:rumunjska
# 2.794446 Y        PredWord:povezan
# 2.779790 Y        PredWord:bukurešt
# 2.761413 Y        ChildWordSet:zbog,spor,plan
# 2.701377 _        PredParentWord:uprti
# 2.638183 _        PredWord:htjeti
# 2.608619 _        DepSubCat:DOBJ,CSUBJ
# 2.585690 Y        PredParentWord:nastati
# 2.568885 _        ChildWordSet:što,pristati
# 2.468990 Y        PredType:participle
# 2.393732 Y        ChildWordSet:oštro
# 2.369380 _        PredParentWord:odan
# 2.354833 _        ChildDepSet:MARK,AUX
# 2.345443 _        PredPos:P
# 2.314798 _        PredParentWord:razasuti
# 2.299645 _        PredDeprel:AUX
# 2.254010 Y        PredWord:voljan
# 2.231269 _        ChildWordSet:,,kako,sebe,,
# 2.210735 _        PredParentWord:evakuirati
# 2.185697 _        PredParentWord:potaknuti
# 2.184962 Y        PredParentWord:većina
# 2.158418 Y        PredWord:predan
# 2.117654 Y        PredDeprel:CCOMP
# 2.107214 _        PredParentWord:poplaviti
# 2.092173 _        ChildTypeSet:,auxiliary,
# 2.085771 Y        PredWord:otkriven
# 2.066530 Y        PredParentWord:snimka
# 2.058686 Y        PredWord:uspostava
# 2.051067 _        ChildWordSet:,,Miona
# 2.044113 Y        PredWord:suprotstavljen
# 2.043878 _        PredParentWord:dijeliti
# 2.034641 _        PredWord:vezati
# 2.024595 _        ChildDepSet:PUNCT,MARK,AUXPASS,NSUBJPASS
# 1.986290 _        ChildDepSet:MARK,NSUBJPASS,AUXPASS
# 1.985453 _        PredWord:predvidjeti
# 1.960235 Y        PredWord:opterećen
# 1.960218 Y        PredWord:kredit
# 1.954761 _        PredParentWord:apstinirati
# 1.953930 Y        PredWord:priznat
# 1.945381 _        PredWord:obuhvatiti
# 1.929766 _        PredParentWord:zaposliti
# 1.929218 _        PredParentWord:položaj
# 1.901931 Y        ChildPOSSet:N,N,V,N,Z
# 1.876301 _        ChildDepSet:AUXPASS,NSUBJPASS
# 1.874715 _        PredPos:M
# 1.862811 _        PredParentWord:zamrznuti
# 1.848751 Y        PredParentWord:opterećen
# 1.847005 _        ChildWordSet:ukoliko,sebe,postupak,,
# 1.815233 _        PredType:
# 1.814365 Y        ChildWordSet:uz
# 1.804967 _        PredWord:pojasniti
# 1.803089 Y        PredParentWord:roditi
# 1.802512 Y        PredWord:predsjedavajući
# 1.787091 Y        ChildWordSet:slika
# 1.785638 Y        PredParentWord:prevariti
# 1.776381 Y        ChildWordSet:cijena
# 1.772260 Y        PredWord:plaćanje
# 1.766567 Y        PredWord:odbijanje
# 1.754924 _        PredDeprel:AMOD
# 1.752606 _        ChildCaseSet:,genitive,,nominative,
# 1.745565 _        ChildWordSet:popis
# 1.733709 _        PredParentWord:dragulj
# 1.726391 Y        PredParentWord:ponuda
# 1.710473 _        PredWord:procijeniti
# 1.708873 Y        ChildWordSet:pristup,poduzetništvo
# 1.708113 Y        DepSubCat:COMPOUND,CASE
# 1.694138 _        PredWord:primjenjivati
# 1.692938 _        PredWord:odustati
# 1.687170 _        ChildDepSet:MARK,AUXPASS,NSUBJPASS
# 1.684611 _        ChildWordSet:koji,sjaj
# 1.670349 _        PredWord:iznijeti
# 1.668939 Y        PredParentWord:kriv
# 1.649110 _        PredParentWord:gledati
# 1.630794 Y        PredWord:nezabilježen
# 1.629902 _        PredWord:razrješavati
# 1.625072 _        PredParentWord:živjeti
# 1.620004 Y        PredWord:udaljen
# 1.615563 _        PredDeprel:DISCOURSE
# 1.608448 _        ChildWordSet:nagrada
# 1.601111 Y        ChildWordSet:daleko
# 1.596142 _        ChildDepSet:MARK,AUX,AUXPASS,NSUBJPASS
# 1.593449 Y        ChildWordSet:istraživanje
# 1.589876 _        PredWord:predvoditi
# 1.586146 Y        PredParentWord:svjestan
# 1.585800 Y        DepSubCat:DOBJ,NUMMOD
# 1.584257 Y        PredParentWord:oslabljen
# 1.583212 _        PredWord:prosvjedovati
# 1.556516 _        PredPos:N
# 1.551939 _        PredWord:požurivati
# 1.551731 Y        PredWord:zaključen
# 1.545646 Y        PredWord:omogućavanje
# 1.541631 _        PredParentWord:selektivan
# 1.538164 _        PredWord:primjećivati
# 1.533650 _        PredWord:poticati
# 1.526198 _        PredDegree:comparative
# 1.514390 _        PredWord:osumnjičiti
# 1.512071 Y        PredParentWord:posljedica
# 1.508066 _        ChildDepSet:PUNCT,CC,CONJ
# 1.506442 _        PredParentWord:anketa
# 1.505070 _        PredParentWord:dati
# 1.500207 _        PredWord:djelovati
# 1.492855 _        PredWord:primati
# 1.491357 Y        DepSubCat:DOBJ,XCOMP
# 1.483008 Y        PredDeprel:ACL
# 1.473137 Y        PredWord:počinjen
# 1.457815 Y        ChildWordSet:datum
# 1.452126 _        PredPos:C
# 1.450524 _        ChildPOSSet:C,P
# 1.450083 _        ChildWordSet:jedino,kredit
# 1.446474 Y        PredWord:postignut
# 1.441562 _        PredParentWord:prihvatljiv
# 1.440555 _        ChildDepSet:AUXPASS,NSUBJPASS,PUNCT
# 1.436286 Y        PredParentWord:dodatak
# 1.436043 _        PredWord:dokazati
# 1.435761 _        PredParentWord:uhićenje
# 1.421085 Y        PredType:main
# 1.412833 Y        ChildCaseSet:,locative
# 1.410648 Y        ChildWordSet:jedan
# 1.408405 _        PredWord:jamčiti
# 1.405494 Y        PredParentWord:dopušten
# 1.402671 _        DepSubCat:ACL,MARK
# 1.395635 Y        ChildDepSet:XCOMP
# 1.393952 Y        PredWord:posvetiti
# 1.389188 Y        PredParentWord:milijarda
# 1.386976 _        ChildWordSet:četvrtak
# 1.384006 Y        ChildWordSet:,,sa,zemlja,standard
# 1.382558 Y        PredWord:otvoren
# 1.380315 _        PredParentWord:snimiti
# 1.376645 Y        PredParentWord:snimatelj
# 1.375214 Y        PredDeprel:ADVCL
# 1.374200 _        PredWord:kretati
# 1.371702 _        PredWord:pristati
# 1.368662 Y        ChildWordSet:sporazum
# 1.357514 _        PredParentWord:žena
# 1.345184 _        ChildWordSet:izložak
# 1.342075 Y        PredPos:R
# 1.340203 Y        PredParentWord:djelo
# 1.336048 _        PredParentWord:imovina
# 1.322102 _        PredParentWord:usuditi
# 1.296656 _        PredWord:zabrinjavati
# 1.296656 _        ChildWordSet:koji,riječ
# 1.286178 Y        ChildCaseSet:genitive,genitive,genitive
# 1.281161 Y        PredWord:pokrenuti
# 1.274277 Y        PredParentWord:birokracija
# 1.273809 _        ChildDepSet:MARK,AUXPASS
# 1.264513 _        PredWord:cjenkati
# 1.258474 Y        PredWord:potapanje
# 1.257474 _        ChildDepSet:PUNCT,MARK,AUXPASS,NSUBJPASS,PUNCT
# 1.257032 _        ChildWordSet:biennale,biti,popis,izvijestiti,.
# 1.256754 Y        ChildWordSet:Allianoi
# 1.255449 Y        DepSubCat:NMOD,XCOMP
# 1.255166 Y        ChildPOSSet:Z,V,N
# 1.252684 _        ChildDepSet:NSUBJPASS
# 1.248354 Y        ChildWordSet:spor,proces
# 1.247037 Y        PredWord:usmjeriti
# 1.246435 _        PredParentWord:poboljšati
# 1.242847 _        PredParentWord:ocijeniti
# 1.241111 Y        PredWord:unaprjeđivanje
# 1.241111 Y        ChildWordSet:princip
# 1.238362 _        ChildTypeSet:,general,auxiliary,
# 1.237217 _        PredWord:predati
# 1.237174 _        DepSubCat:DOBJ,CCOMP,MARK
# 1.235636 Y        ChildPOSSet:Z,S,N,N
# 1.233871 Y        PredParentWord:slučaj
# 1.232926 _        PredWord:podignuti
# 1.232507 Y        ChildDepSet:COP,NMOD
# 1.227123 Y        ChildWordSet:članstvo
# 1.222540 Y        DepSubCat:XCOMP,XCOMP
# 1.219917 _        DepSubCat:ACL,NSUBJ,MARK,DOBJ
# 1.219917 _        ChildWordSet:da,zemlja,središte
# 1.212254 _        PredDeprel:NSUBJPASS
# 1.206443 _        PredWord:evakuirati
# 1.204745 Y        ChildDepSet:ADVMOD,ADVCL
# 1.202747 _        PredVForm:
# 1.198170 Y        PredParentWord:potpisati
# 1.191932 _        DepSubCat:PUNCT,NSUBJPASS,ROOT,AUXPASS,ADVMOD
# 1.184738 _        PredWord:suočiti
# 1.176756 _        PredWord:surađivati
# 1.173800 _        ChildCaseSet:,locative,,nominative,
# 1.169115 _        ChildDepSet:MARK,AUX,NSUBJPASS,AUXPASS,ADVMOD
# 1.160412 Y        ChildDepSet:DISCOURSE,NSUBJ,NMOD,ADVMOD,COP,PUNCT
# 1.160412 Y        ChildPOSSet:R,N,N,R,V,Z
# 1.160352 _        DepSubCat:CSUBJ,DOBJ,MARK
# 1.156658 _        ChildPOSSet:Z,R,V,Z
# 1.150616 _        ChildWordSet:da,izlaz
# 1.147653 _        ChildTypeSet:indefinite,reflexive
# 1.147084 Y        PredParentWord:uništiti
# 1.137644 _        DepSubCat:CCOMP,NMOD,NSUBJPASS,AUXPASS,MARK
# 1.137644 _        ChildWordSet:kako,biti,siromaštvo,kontinent
# 1.135664 Y        PredDeprel:COP
# 1.135583 Y        PredParentWord:ostvarenje
# 1.127071 Y        DepSubCat:NMOD,NMOD,NMOD,CASE,PUNCT
# 1.121539 Y        PredWord:trebati
# 1.120513 Y        PredParentWord:reforma
# 1.117658 Y        ChildDepSet:PUNCT,CASE,NMOD,NMOD
# 1.113961 _        ChildWordSet:srijeda
# 1.113734 _        DepSubCat:NMOD,ACL,ADVMOD
# 1.113734 _        ChildWordSet:prijeko,usmjeravanje
# 1.104384 _        DepSubCat:AUXPASS,ROOT,PUNCT,CSUBJPASS,NMOD
# 1.104384 _        ChildWordSet:ured,biti,predsjednik,.
# 1.094295 Y        PredParentWord:održati
# 1.092435 _        PredParentWord:uspostava
# 1.091217 _        ChildDepSet:PUNCT,MARK,COMPOUND,PUNCT
# 1.090850 _        PredWord:sabotirati
# 1.090850 _        ChildWordSet:da,misija
# 1.084593 _        PredParentWord:pravo
# 1.083322 Y        PredWord:pad
# 1.082692 _        ChildWordSet:izvješće,biti,dužnosnik,.
# 1.082117 Y        DepSubCat:XCOMP,ADVMOD
# 1.075301 Y        ChildDepSet:ADVCL
# 1.073238 _        ChildCaseSet:,dative,nominative
# 1.069668 Y        PredParentWord:poduzeti
# 1.067178 _        PredWord:zaštititi
# 1.064534 _        PredWord:unaprijediti
# 1.063939 _        ChildPOSSet:C,V
# 1.063686 _        PredParentWord:birati
# 1.063192 Y        PredWord:uvjeren
# 1.058971 _        ChildDepSet:MARK,COP,NSUBJ
# 1.055900 _        PredParentWord:postignut
# 1.055422 _        ChildWordSet:kad
# 1.054651 _        PredParentWord:šetati
# 1.053677 _        ChildDepSet:AUX,PUNCT
# 1.053677 _        ChildWordSet:biti,,
# 1.053677 _        ChildTypeSet:auxiliary,
# 1.052806 _        PredWord:plivati
# 1.048881 Y        ChildWordSet:na,klima,,,zaključivanje,i,omogućavanje
# 1.047334 Y        DepSubCat:XCOMP,CONJ,MARK
# 1.045699 _        PredParentWord:neprikladno
# 1.022039 Y        ChildWordSet:prijam
# 1.022020 _        ChildWordSet:,,stručnjak
# 1.006209 _        ChildWordSet:vladavina
# 0.999915 _        PredParentWord:obrazovati
# 0.998141 _        ChildDepSet:MARK,COP
# 0.993333 _        PredWord:izmijeniti
# 0.989176 Y        PredWord:vezano
# 0.985521 Y        ChildCaseSet:accusative,,
# 0.984649 _        PredWord:nastaniti
# 0.977791 _        PredParentWord:uvjeren
# 0.975149 Y        ChildTypeSet:common,auxiliary,general
# 0.974343 _        PredWord:ticati
# 0.974343 _        ChildDepSet:MARK,COMPOUND,DOBJ,PUNCT
# 0.973049 Y        PredParentWord:uzeti
# 0.971981 _        ChildWordSet:stjecanje
# 0.968746 _        PredCase:genitive
# 0.965229 Y        PredWord:inspiriran
# 0.964674 _        PredWord:slušati
# 0.958439 Y        ChildDepSet:PUNCT,CCOMP
# 0.957700 Y        PredParentWord:pravedan
# 0.955219 _        PredParentWord:mogućnost
# 0.954321 _        ChildWordSet:koji,biti,EU
# 0.948520 _        PredType:common
# 0.948492 Y        PredWord:zabrinut
# 0.947140 Y        PredWord:održati
# 0.946254 Y        PredWord:provedba
# 0.940709 Y        ChildWordSet:,,nakon,Brussels,dan
# 0.940709 Y        ChildCaseSet:,genitive,dative,genitive
# 0.940064 Y        ChildWordSet:provedba
# 0.937880 _        PredWord:narušiti
# 0.934766 Y        ChildTypeSet:,,proper,common
# 0.933298 _        ChildWordSet:politički
# 0.932633 Y        ChildPOSSet:Z,P,N
# 0.931157 _        PredWord:ići
# 0.930837 _        ChildPOSSet:P,P,N,Z
# 0.929191 _        PredWord:učiniti
# 0.925663 Y        ChildCaseSet:,nominative,,locative,
# 0.919611 _        PredWord:predložiti
# 0.918966 Y        PredWord:pregledati
# 0.918966 Y        ChildWordSet:i,prebaciti
# 0.915918 _        DepSubCat:ACL,NMOD
# 0.914557 _        PredWord:definirati
# 0.912161 _        ChildWordSet:apatija
# 0.912088 _        PredWord:ponuditi
# 0.911062 Y        PredVForm:participle
# 0.907461 _        ChildDepSet:MARK,NEG
# 0.907461 _        ChildPOSSet:C,Q
# 0.907461 _        ChildTypeSet:subordinating,negative
# 0.906819 Y        DepSubCat:NMOD,CCOMP,COP,NSUBJ,AUX,MARK
# 0.904325 _        PredParentWord:rok
# 0.904036 _        PredVForm:aorist
# 0.900220 _        PredWord:promijeniti
# 0.899487 _        DepSubCat:ADVCL,MARK,CCOMP
# 0.899487 _        ChildWordSet:jer,opadati
# 0.896041 Y        DepSubCat:NMOD,NMOD
# 0.889468 Y        ChildDepSet:NSUBJPASS,AUXPASS,NMOD,PUNCT
# 0.887792 _        ChildTypeSet:common,auxiliary,auxiliary
# 0.887535 _        DepSubCat:NSUBJ,AUX,MARK,NMOD,ACL
# 0.882146 Y        ChildWordSet:sada
# 0.881244 _        PredParentDeprel:AMOD
# 0.879903 _        PredParentWord:moguć
# 0.879249 _        PredParentWord:dovesti
# 0.879157 Y        PredWord:uslijediti
# 0.877473 Y        ChildWordSet:dobro
# 0.876381 Y        ChildDepSet:PUNCT,NMOD,PUNCT
#
# Top negative:
# -0.876381 _        ChildDepSet:PUNCT,NMOD,PUNCT
# -0.877473 _        ChildWordSet:dobro
# -0.879157 _        PredWord:uslijediti
# -0.879249 Y        PredParentWord:dovesti
# -0.879903 Y        PredParentWord:moguć
# -0.881244 Y        PredParentDeprel:AMOD
# -0.882146 _        ChildWordSet:sada
# -0.887535 Y        DepSubCat:NSUBJ,AUX,MARK,NMOD,ACL
# -0.887792 Y        ChildTypeSet:common,auxiliary,auxiliary
# -0.889468 _        ChildDepSet:NSUBJPASS,AUXPASS,NMOD,PUNCT
# -0.896041 _        DepSubCat:NMOD,NMOD
# -0.899487 Y        DepSubCat:ADVCL,MARK,CCOMP
# -0.899487 Y        ChildWordSet:jer,opadati
# -0.900220 Y        PredWord:promijeniti
# -0.904036 Y        PredVForm:aorist
# -0.904325 Y        PredParentWord:rok
# -0.906819 _        DepSubCat:NMOD,CCOMP,COP,NSUBJ,AUX,MARK
# -0.907461 Y        ChildDepSet:MARK,NEG
# -0.907461 Y        ChildPOSSet:C,Q
# -0.907461 Y        ChildTypeSet:subordinating,negative
# -0.911062 _        PredVForm:participle
# -0.912088 Y        PredWord:ponuditi
# -0.912161 Y        ChildWordSet:apatija
# -0.914557 Y        PredWord:definirati
# -0.915918 Y        DepSubCat:ACL,NMOD
# -0.918966 _        PredWord:pregledati
# -0.918966 _        ChildWordSet:i,prebaciti
# -0.919611 Y        PredWord:predložiti
# -0.925663 _        ChildCaseSet:,nominative,,locative,
# -0.929191 Y        PredWord:učiniti
# -0.930837 Y        ChildPOSSet:P,P,N,Z
# -0.931157 Y        PredWord:ići
# -0.932633 _        ChildPOSSet:Z,P,N
# -0.933298 Y        ChildWordSet:politički
# -0.934766 _        ChildTypeSet:,,proper,common
# -0.937880 Y        PredWord:narušiti
# -0.940064 _        ChildWordSet:provedba
# -0.940709 _        ChildWordSet:,,nakon,Brussels,dan
# -0.940709 _        ChildCaseSet:,genitive,dative,genitive
# -0.946254 _        PredWord:provedba
# -0.947140 _        PredWord:održati
# -0.948492 _        PredWord:zabrinut
# -0.948520 Y        PredType:common
# -0.954321 Y        ChildWordSet:koji,biti,EU
# -0.955219 Y        PredParentWord:mogućnost
# -0.957700 _        PredParentWord:pravedan
# -0.958439 _        ChildDepSet:PUNCT,CCOMP
# -0.964674 Y        PredWord:slušati
# -0.965229 _        PredWord:inspiriran
# -0.968746 Y        PredCase:genitive
# -0.971981 Y        ChildWordSet:stjecanje
# -0.973049 _        PredParentWord:uzeti
# -0.974343 Y        PredWord:ticati
# -0.974343 Y        ChildDepSet:MARK,COMPOUND,DOBJ,PUNCT
# -0.975149 _        ChildTypeSet:common,auxiliary,general
# -0.977791 Y        PredParentWord:uvjeren
# -0.984649 Y        PredWord:nastaniti
# -0.985521 _        ChildCaseSet:accusative,,
# -0.989176 _        PredWord:vezano
# -0.993333 Y        PredWord:izmijeniti
# -0.998141 Y        ChildDepSet:MARK,COP
# -0.999915 Y        PredParentWord:obrazovati
# -1.006209 Y        ChildWordSet:vladavina
# -1.022020 Y        ChildWordSet:,,stručnjak
# -1.022039 _        ChildWordSet:prijam
# -1.045699 Y        PredParentWord:neprikladno
# -1.047334 _        DepSubCat:XCOMP,CONJ,MARK
# -1.048881 _        ChildWordSet:na,klima,,,zaključivanje,i,omogućavanje
# -1.052806 Y        PredWord:plivati
# -1.053677 Y        ChildDepSet:AUX,PUNCT
# -1.053677 Y        ChildWordSet:biti,,
# -1.053677 Y        ChildTypeSet:auxiliary,
# -1.054651 Y        PredParentWord:šetati
# -1.055422 Y        ChildWordSet:kad
# -1.055900 Y        PredParentWord:postignut
# -1.058971 Y        ChildDepSet:MARK,COP,NSUBJ
# -1.063192 _        PredWord:uvjeren
# -1.063686 Y        PredParentWord:birati
# -1.063939 Y        ChildPOSSet:C,V
# -1.064534 Y        PredWord:unaprijediti
# -1.067178 Y        PredWord:zaštititi
# -1.069668 _        PredParentWord:poduzeti
# -1.073238 Y        ChildCaseSet:,dative,nominative
# -1.075301 _        ChildDepSet:ADVCL
# -1.082117 _        DepSubCat:XCOMP,ADVMOD
# -1.082692 Y        ChildWordSet:izvješće,biti,dužnosnik,.
# -1.083322 _        PredWord:pad
# -1.084593 Y        PredParentWord:pravo
# -1.090850 Y        PredWord:sabotirati
# -1.090850 Y        ChildWordSet:da,misija
# -1.091217 Y        ChildDepSet:PUNCT,MARK,COMPOUND,PUNCT
# -1.092435 Y        PredParentWord:uspostava
# -1.094295 _        PredParentWord:održati
# -1.104384 Y        DepSubCat:AUXPASS,ROOT,PUNCT,CSUBJPASS,NMOD
# -1.104384 Y        ChildWordSet:ured,biti,predsjednik,.
# -1.113734 Y        DepSubCat:NMOD,ACL,ADVMOD
# -1.113734 Y        ChildWordSet:prijeko,usmjeravanje
# -1.113961 Y        ChildWordSet:srijeda
# -1.117658 _        ChildDepSet:PUNCT,CASE,NMOD,NMOD
# -1.120513 _        PredParentWord:reforma
# -1.121539 _        PredWord:trebati
# -1.127071 _        DepSubCat:NMOD,NMOD,NMOD,CASE,PUNCT
# -1.135583 _        PredParentWord:ostvarenje
# -1.135664 _        PredDeprel:COP
# -1.137644 Y        DepSubCat:CCOMP,NMOD,NSUBJPASS,AUXPASS,MARK
# -1.137644 Y        ChildWordSet:kako,biti,siromaštvo,kontinent
# -1.147084 _        PredParentWord:uništiti
# -1.147653 Y        ChildTypeSet:indefinite,reflexive
# -1.150616 Y        ChildWordSet:da,izlaz
# -1.156658 Y        ChildPOSSet:Z,R,V,Z
# -1.160352 Y        DepSubCat:CSUBJ,DOBJ,MARK
# -1.160412 _        ChildDepSet:DISCOURSE,NSUBJ,NMOD,ADVMOD,COP,PUNCT
# -1.160412 _        ChildPOSSet:R,N,N,R,V,Z
# -1.169115 Y        ChildDepSet:MARK,AUX,NSUBJPASS,AUXPASS,ADVMOD
# -1.173800 Y        ChildCaseSet:,locative,,nominative,
# -1.176756 Y        PredWord:surađivati
# -1.184738 Y        PredWord:suočiti
# -1.191932 Y        DepSubCat:PUNCT,NSUBJPASS,ROOT,AUXPASS,ADVMOD
# -1.198170 _        PredParentWord:potpisati
# -1.202747 Y        PredVForm:
# -1.204745 _        ChildDepSet:ADVMOD,ADVCL
# -1.206443 Y        PredWord:evakuirati
# -1.212254 Y        PredDeprel:NSUBJPASS
# -1.219917 Y        DepSubCat:ACL,NSUBJ,MARK,DOBJ
# -1.219917 Y        ChildWordSet:da,zemlja,središte
# -1.222540 _        DepSubCat:XCOMP,XCOMP
# -1.227123 _        ChildWordSet:članstvo
# -1.232507 _        ChildDepSet:COP,NMOD
# -1.232926 Y        PredWord:podignuti
# -1.233871 _        PredParentWord:slučaj
# -1.235636 _        ChildPOSSet:Z,S,N,N
# -1.237174 Y        DepSubCat:DOBJ,CCOMP,MARK
# -1.237217 Y        PredWord:predati
# -1.238362 Y        ChildTypeSet:,general,auxiliary,
# -1.241111 _        PredWord:unaprjeđivanje
# -1.241111 _        ChildWordSet:princip
# -1.242847 Y        PredParentWord:ocijeniti
# -1.246435 Y        PredParentWord:poboljšati
# -1.247037 _        PredWord:usmjeriti
# -1.248354 _        ChildWordSet:spor,proces
# -1.252684 Y        ChildDepSet:NSUBJPASS
# -1.255166 _        ChildPOSSet:Z,V,N
# -1.255449 _        DepSubCat:NMOD,XCOMP
# -1.256754 _        ChildWordSet:Allianoi
# -1.257032 Y        ChildWordSet:biennale,biti,popis,izvijestiti,.
# -1.257474 Y        ChildDepSet:PUNCT,MARK,AUXPASS,NSUBJPASS,PUNCT
# -1.258474 _        PredWord:potapanje
# -1.264513 Y        PredWord:cjenkati
# -1.273809 Y        ChildDepSet:MARK,AUXPASS
# -1.274277 _        PredParentWord:birokracija
# -1.281161 _        PredWord:pokrenuti
# -1.286178 _        ChildCaseSet:genitive,genitive,genitive
# -1.296656 Y        PredWord:zabrinjavati
# -1.296656 Y        ChildWordSet:koji,riječ
# -1.322102 Y        PredParentWord:usuditi
# -1.336048 Y        PredParentWord:imovina
# -1.340203 _        PredParentWord:djelo
# -1.342075 _        PredPos:R
# -1.345184 Y        ChildWordSet:izložak
# -1.357514 Y        PredParentWord:žena
# -1.368662 _        ChildWordSet:sporazum
# -1.371702 Y        PredWord:pristati
# -1.374200 Y        PredWord:kretati
# -1.375214 _        PredDeprel:ADVCL
# -1.376645 _        PredParentWord:snimatelj
# -1.380315 Y        PredParentWord:snimiti
# -1.382558 _        PredWord:otvoren
# -1.384006 _        ChildWordSet:,,sa,zemlja,standard
# -1.386976 Y        ChildWordSet:četvrtak
# -1.389188 _        PredParentWord:milijarda
# -1.393952 _        PredWord:posvetiti
# -1.395635 _        ChildDepSet:XCOMP
# -1.402671 Y        DepSubCat:ACL,MARK
# -1.405494 _        PredParentWord:dopušten
# -1.408405 Y        PredWord:jamčiti
# -1.410648 _        ChildWordSet:jedan
# -1.412833 _        ChildCaseSet:,locative
# -1.421085 _        PredType:main
# -1.435761 Y        PredParentWord:uhićenje
# -1.436043 Y        PredWord:dokazati
# -1.436286 _        PredParentWord:dodatak
# -1.440555 Y        ChildDepSet:AUXPASS,NSUBJPASS,PUNCT
# -1.441562 Y        PredParentWord:prihvatljiv
# -1.446474 _        PredWord:postignut
# -1.450083 Y        ChildWordSet:jedino,kredit
# -1.450524 Y        ChildPOSSet:C,P
# -1.452126 Y        PredPos:C
# -1.457815 _        ChildWordSet:datum
# -1.473137 _        PredWord:počinjen
# -1.483008 _        PredDeprel:ACL
# -1.491357 _        DepSubCat:DOBJ,XCOMP
# -1.492855 Y        PredWord:primati
# -1.500207 Y        PredWord:djelovati
# -1.505070 Y        PredParentWord:dati
# -1.506442 Y        PredParentWord:anketa
# -1.508066 Y        ChildDepSet:PUNCT,CC,CONJ
# -1.512071 _        PredParentWord:posljedica
# -1.514390 Y        PredWord:osumnjičiti
# -1.526198 Y        PredDegree:comparative
# -1.533650 Y        PredWord:poticati
# -1.538164 Y        PredWord:primjećivati
# -1.541631 Y        PredParentWord:selektivan
# -1.545646 _        PredWord:omogućavanje
# -1.551731 _        PredWord:zaključen
# -1.551939 Y        PredWord:požurivati
# -1.556516 Y        PredPos:N
# -1.583212 Y        PredWord:prosvjedovati
# -1.584257 _        PredParentWord:oslabljen
# -1.585800 _        DepSubCat:DOBJ,NUMMOD
# -1.586146 _        PredParentWord:svjestan
# -1.589876 Y        PredWord:predvoditi
# -1.593449 _        ChildWordSet:istraživanje
# -1.596142 Y        ChildDepSet:MARK,AUX,AUXPASS,NSUBJPASS
# -1.601111 _        ChildWordSet:daleko
# -1.608448 Y        ChildWordSet:nagrada
# -1.615563 Y        PredDeprel:DISCOURSE
# -1.620004 _        PredWord:udaljen
# -1.625072 Y        PredParentWord:živjeti
# -1.629902 Y        PredWord:razrješavati
# -1.630794 _        PredWord:nezabilježen
# -1.649110 Y        PredParentWord:gledati
# -1.668939 _        PredParentWord:kriv
# -1.670349 Y        PredWord:iznijeti
# -1.684611 Y        ChildWordSet:koji,sjaj
# -1.687170 Y        ChildDepSet:MARK,AUXPASS,NSUBJPASS
# -1.692938 Y        PredWord:odustati
# -1.694138 Y        PredWord:primjenjivati
# -1.708113 _        DepSubCat:COMPOUND,CASE
# -1.708873 _        ChildWordSet:pristup,poduzetništvo
# -1.710473 Y        PredWord:procijeniti
# -1.726391 _        PredParentWord:ponuda
# -1.733709 Y        PredParentWord:dragulj
# -1.745565 Y        ChildWordSet:popis
# -1.752606 Y        ChildCaseSet:,genitive,,nominative,
# -1.754924 Y        PredDeprel:AMOD
# -1.766567 _        PredWord:odbijanje
# -1.772260 _        PredWord:plaćanje
# -1.776381 _        ChildWordSet:cijena
# -1.785638 _        PredParentWord:prevariti
# -1.787091 _        ChildWordSet:slika
# -1.802512 _        PredWord:predsjedavajući
# -1.803089 _        PredParentWord:roditi
# -1.804967 Y        PredWord:pojasniti
# -1.814365 _        ChildWordSet:uz
# -1.815233 Y        PredType:
# -1.847005 Y        ChildWordSet:ukoliko,sebe,postupak,,
# -1.848751 _        PredParentWord:opterećen
# -1.862811 Y        PredParentWord:zamrznuti
# -1.874715 Y        PredPos:M
# -1.876301 Y        ChildDepSet:AUXPASS,NSUBJPASS
# -1.901931 _        ChildPOSSet:N,N,V,N,Z
# -1.929218 Y        PredParentWord:položaj
# -1.929766 Y        PredParentWord:zaposliti
# -1.945381 Y        PredWord:obuhvatiti
# -1.953930 _        PredWord:priznat
# -1.954761 Y        PredParentWord:apstinirati
# -1.960218 _        PredWord:kredit
# -1.960235 _        PredWord:opterećen
# -1.985453 Y        PredWord:predvidjeti
# -1.986290 Y        ChildDepSet:MARK,NSUBJPASS,AUXPASS
# -2.024595 Y        ChildDepSet:PUNCT,MARK,AUXPASS,NSUBJPASS
# -2.034641 Y        PredWord:vezati
# -2.043878 Y        PredParentWord:dijeliti
# -2.044113 _        PredWord:suprotstavljen
# -2.051067 Y        ChildWordSet:,,Miona
# -2.058686 _        PredWord:uspostava
# -2.066530 _        PredParentWord:snimka
# -2.085771 _        PredWord:otkriven
# -2.092173 Y        ChildTypeSet:,auxiliary,
# -2.107214 Y        PredParentWord:poplaviti
# -2.117654 _        PredDeprel:CCOMP
# -2.158418 _        PredWord:predan
# -2.184962 _        PredParentWord:većina
# -2.185697 Y        PredParentWord:potaknuti
# -2.210735 Y        PredParentWord:evakuirati
# -2.231269 Y        ChildWordSet:,,kako,sebe,,
# -2.254010 _        PredWord:voljan
# -2.299645 Y        PredDeprel:AUX
# -2.314798 Y        PredParentWord:razasuti
# -2.345443 Y        PredPos:P
# -2.354833 Y        ChildDepSet:MARK,AUX
# -2.369380 Y        PredParentWord:odan
# -2.393732 _        ChildWordSet:oštro
# -2.468990 _        PredType:participle
# -2.568885 Y        ChildWordSet:što,pristati
# -2.585690 _        PredParentWord:nastati
# -2.608619 Y        DepSubCat:DOBJ,CSUBJ
# -2.638183 Y        PredWord:htjeti
# -2.701377 Y        PredParentWord:uprti
# -2.761413 _        ChildWordSet:zbog,spor,plan
# -2.779790 _        PredWord:bukurešt
# -2.794446 _        PredWord:povezan
# -2.841478 _        PredWord:rumunjska
# -2.865765 Y        PredParentWord:dirnuti
# -2.923477 Y        ChildDepSet:MARK
# -3.055432 _        PredWord:zaključivanje
# -3.178922 _        PredWord:zainteresiran
# -3.248193 _        PredWord:spreman
# -3.282619 Y        ChildDepSet:MARK,COMPOUND
# -4.289948 _        PredWord:podrijetlo

# %%
from sklearn.externals import joblib
joblib.dump(model, 'pi.pkl')
# Out:
# ['pi.pkl']

# %%
def custom_flatten (X, y):
    data = [feature for sentence in X for feature in sentence]
    labels = [label for sentence in y for label in sentence]
    return data, labels
X_train, y_train = custom_flatten (X_train, y_train)
X_test, y_test = custom_flatten (X_test, y_test)

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression
#from sklearn.svm import LinearSVC

vec = DictVectorizer(sparse=True)
enc = preprocessing.LabelEncoder()

clf = LogisticRegression(solver='lbfgs')

X = vec.fit_transform(X_train)
y = enc.fit_transform(y_train)
clf.fit(X,y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='lbfgs', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
X_test = vec.transform(X_test)
y_pred = clf.predict(X_test)
y_pred = enc.inverse_transform(y_pred)
# Out:
# /home/daniel/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
from sklearn.metrics import classification_report
labels = list(enc.classes_)
print(classification_report(y_test, y_pred, target_names=labels, digits=4))
# Out:
#              precision    recall  f1-score   support
#
#           Y       0.96      0.97      0.96      2021
#           _       1.00      0.99      1.00     14614
#
# avg / total       0.99      0.99      0.99     16635
